# %% [markdown]
# # 🧠 Agentic AI: From Hype to Handleable Systems — Future-Ready Masterclass (v8)
#
# This notebook is designed for a **live Colab demo** aligned to your talk:
#
# > *Agentic AI: From Hype to Handleable Systems — What’s real now, what’s next, and how to deploy it responsibly.*
#
# We focus on **real, online agentic behavior** using GPT-4o-mini via the **Great Learning proxy**, with:
#
# - Multi-agent patterns (Researcher → Writer → Critic → Judge)
# - Budget- and latency-aware orchestration
# - Slide-aligned use cases:
#   - UC1: Hybrid orchestration
#   - UC2: Operating modes & LOA-A
#   - UC3: Truth tests & meta "future scan"
#   - UC4: Procurement-prompt auditor
#   - UC5: Frontier signals monitor
#
# **All LLM calls in UC1–UC4 are real online calls via GPT-4o-mini.**
# UC5 uses the same model but is explicitly framed as **heuristic frontier signals**, not measured telemetry.
#
# ---
#
# ## 🔑 Great Learning API key (Colab)
#
# In **Colab**, set your key once per session before running the agents:
#
# ```python
# from google.colab import userdata
# userdata.set("GL_OpenAI", "sk-...your-key-here...")
# ```
#
# This notebook will read it via `userdata.get("GL_OpenAI")`.
# If that’s not available, it will fall back to the `GL_OpenAI` environment variable.
#
#
#
# Uncomment the `pip install` line if `openai` or `pandas` is not available in your runtime.

# %% [markdown]
# # 0. Install + Imports

# %%
# !pip install -q openai pandas

# %%
import os, time, json
from dataclasses import dataclass
from typing import List, Dict, Any, Optional, Union
import textwrap # Import the textwrap module

import pandas as pd
from IPython.display import display, HTML

from openai import OpenAI

# Try to get GL key from Colab, else env var
GL_KEY = None
try:
    from google.colab import userdata  # type: ignore
    GL_KEY = userdata.get("openAI")
except Exception:
    GL_KEY = os.getenv("openAI")

MODE = "ONLINE"
API_BASE = "https://api.openai.com/v1" #Change to great learning API Base
MODEL_ID = "gpt-4o-mini"
EMBED_MODEL = "text-embedding-3-small"

if not GL_KEY:
    print("⚠️ GL_OpenAI key not found. Set it via `userdata.set('GL_OpenAI', '...')` or env var before heavy runs.")

client = OpenAI(
    base_url=API_BASE,
    api_key=GL_KEY or "sk-placeholder",  # will fail if actually used without a real key
)

# Simple pricing heuristic (USD per token)
PRICING = {
    "gpt-4o-mini": {
        "input_per_token": 0.15 / 1_000_000,
        "output_per_token": 0.60 / 1_000_000,
    }
}

def estimate_cost(model: str, prompt_toks: int, comp_toks: int) -> float:
    cfg = PRICING.get(model, PRICING["gpt-4o-mini"])
    return (
        cfg["input_per_token"] * float(prompt_toks)
        + cfg["output_per_token"] * float(comp_toks)
    )


def show_runtime_status():
    key_status = "✅" if GL_KEY else "⚠️"
    html = f"""
    <div style="border-radius:10px;padding:10px 14px;margin:8px 0;
                background:#f1f5f9;font-size:14px;">
      <b>Runtime:</b> MODE = <code>{MODE}</code> · Model = <code>{MODEL_ID}</code> ·
      API_BASE = <code>{API_BASE}</code><br/>
      <b>GL_OpenAI key:</b> {key_status} {'configured' if GL_KEY else 'missing'}
    </div>
    """
    display(HTML(html))


show_runtime_status()
# Out:
#     <div style="border-radius:10px;padding:10px 14px;margin:8px 0;
#                 background:#f1f5f9;font-size:14px;">
#       <b>Runtime:</b> MODE = <code>ONLINE</code> · Model = <code>gpt-4o-mini</code> ·
#       API_BASE = <code>https://api.openai.com/v1</code><br/>
#       <b>GL_OpenAI key:</b> ✅ configured
#     </div>

# %% [markdown]
# ## 1. Display Helpers
#
# Seminar-friendly helpers:
# - `show_card` – explanation blocks
# - `show_badge` – PASS/FAIL / info pills
# - `show_json` – prettified JSON
# - `show_table` – simple Pandas tables

# %%
def show_card(title: str, body: str, kind: str = "info"):
    colors = {
        "info": ("#0ea5e9", "#f0f9ff"),
        "success": ("#16a34a", "#ecfdf5"),
        "warn": ("#f59e0b", "#fffbeb"),
        "error": ("#dc2626", "#fef2f2"),
        "neutral": ("#6b7280", "#f4f4f5"),
    }
    fg, bg = colors.get(kind, colors["info"])
    html = f"""
    <div style="border-radius:12px;padding:12px 14px;margin:10px 0;
                border:1px solid {fg};background:{bg};">
      <div style="font-weight:700;color:{fg};margin-bottom:4px;">{title}</div>
      <div style="white-space:pre-wrap;line-height:1.4;font-size:14px;">{body}</div>
    </div>
    """
    display(HTML(html))


def show_badge(text: str, kind: str = "success"):
    colors = {
        "success": ("#16a34a", "#ecfdf5"),
        "fail": ("#dc2626", "#fef2f2"),
        "warn": ("#f59e0b", "#fffbeb"),
        "info": ("#0ea5e9", "#f0f9ff"),
        "neutral": ("#6b7280", "#f4f4f5"),
    }
    fg, bg = colors.get(kind, colors["info"])
    html = f"""
    <span style="display:inline-block;padding:4px 10px;border-radius:999px;
                 font-size:12px;font-weight:600;color:{fg};background:{bg};
                 margin:4px 0;">
      {text}
    </span>
    """
    display(HTML(html))


def show_json(obj: Any, title: str = "JSON"):
    display(HTML(f"<div style='font-weight:600;margin:6px 0;'>{title}</div>"))
    body = json.dumps(obj, indent=2)

    # 2. Wrap the text to the maximum width
    wrapped_body = textwrap.fill(body, width=150, subsequent_indent='\n ')


    display(HTML(
        "<pre style='background:#020617;color:#e5e7eb;"
        "padding:10px;border-radius:8px;font-size:12px;'>" +
        wrapped_body +
        "</pre>"
    ))


def show_table(df: pd.DataFrame, title: str = "Table"):
    display(HTML(f"<div style='font-weight:600;margin:6px 0;'>{title}</div>"))
    display(df.style.set_table_styles(
        [{'selector': 'th', 'props': [('background-color', '#e5e7eb')]}]
    ))

# %% [markdown]
# ## 2. LLM Call Wrapper & Cost/Latency Logging
#
# `call_llm` is a minimal wrapper around GPT-4o-mini via the Great Learning proxy.
# It returns `text` plus a `meta` dict with:
# - `prompt_tokens`, `completion_tokens`, `total_tokens`
# - `latency_s`, `cost_usd` (using a simple heuristic)
#
# `log_agent_run` stores per-agent metrics, and `show_run_summary` prints a table.

# %%
@dataclass
class AgentRun:
    use_case: str
    agent_name: str
    role: str
    model: str
    prompt_tokens: int
    completion_tokens: int
    total_tokens: int
    latency_s: float
    cost_usd: float


def call_llm(
    messages: List[Dict[str, str]],
    model: str = MODEL_ID,
    temperature: float = 0.2,
    max_tokens: int = 800,
) -> (str, Dict[str, Any]):
    t0 = time.time()
    resp = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
    )
    dt = time.time() - t0
    msg = resp.choices[0].message
    text = msg.content
    usage = resp.usage
    prompt_tokens = usage.prompt_tokens if usage else 0
    completion_tokens = usage.completion_tokens if usage else 0
    total_tokens = usage.total_tokens if usage else (prompt_tokens + completion_tokens)
    cost_usd = estimate_cost(model, prompt_tokens, completion_tokens)
    meta = {
        "prompt_tokens": prompt_tokens,
        "completion_tokens": completion_tokens,
        "total_tokens": total_tokens,
        "latency_s": dt,
        "cost_usd": cost_usd,
        "model": model,
    }
    return text, meta


all_runs: List[AgentRun] = []


def log_agent_run(
    use_case: str,
    agent_name: str,
    role: str,
    meta: Dict[str, Any],
):
    run = AgentRun(
        use_case=use_case,
        agent_name=agent_name,
        role=role,
        model=meta["model"],
        prompt_tokens=meta["prompt_tokens"],
        completion_tokens=meta["completion_tokens"],
        total_tokens=meta["total_tokens"],
        latency_s=meta["latency_s"],
        cost_usd=meta["cost_usd"],
    )
    all_runs.append(run)
    show_badge(
        f"{use_case} · {agent_name} ({role}) — {meta['total_tokens']} tok, {meta['latency_s']:.2f}s, ${meta['cost_usd']:.4f}",
        kind="info",
    )


def show_run_summary(use_case: str):
    uc_runs = [r for r in all_runs if r.use_case == use_case]
    if not uc_runs:
        show_card(f"{use_case} — No runs logged", "", kind="warn")
        return
    rows = [
        {
            "Agent": r.agent_name,
            "Role": r.role,
            "Model": r.model,
            "Prompt tok": r.prompt_tokens,
            "Completion tok": r.completion_tokens,
            "Total tok": r.total_tokens,
            "Latency (s)": round(r.latency_s, 2),
            "Cost (USD)": round(r.cost_usd, 6),
        }
        for r in uc_runs
    ]
    df = pd.DataFrame(rows)
    totals = pd.DataFrame([
        {
            "Agent": "TOTAL",
            "Role": "—",
            "Model": "—",
            "Prompt tok": df["Prompt tok"].sum(),
            "Completion tok": df["Completion tok"].sum(),
            "Total tok": df["Total tok"].sum(),
            "Latency (s)": round(df["Latency (s)"].sum(), 2),
            "Cost (USD)": round(df["Cost (USD)"].sum(), 6),
        }
    ])
    show_table(pd.concat([df, totals], ignore_index=True), f"{use_case} — Cost/Latency Summary")
    total_cost = totals["Cost (USD)"].iloc[0]
    badge_kind = "success" if total_cost <= 0.50 else "warn"
    show_badge(f"{use_case} Budget: ${total_cost:.4f}", kind=badge_kind)

# %% [markdown]
# ## 3. Agent Roles & Judge
#
# We implement agents as **functions with different system prompts**:
#
# - **Researcher** — decomposes the task, outlines sections, identifies evidence
# - **Writer** — produces structured drafts with assumptions and limitations
# - **Critic** — gives actionable, targeted edits (no full rewrite)
# - **Judge** — returns **strict JSON** for rubric scoring
#
# This keeps the code simple and transparent for teaching.

# %%
def researcher_agent(task: str, use_case: str) -> str:
    messages = [
        {
            "role": "system",
            "content": (
                "You are the Researcher agent in a multi-agent system. "
                "Decompose the task, propose sections, and identify evidence angles. "
                "Do NOT write the final narrative; instead, return an outline with bullets."
            ),
        },
        {"role": "user", "content": task},
    ]
    text, meta = call_llm(messages, model=MODEL_ID)
    log_agent_run(use_case, "Researcher", "analysis/outline", meta)
    return text


def writer_agent(context: str, use_case: str) -> str:
    messages = [
        {
            "role": "system",
            "content": (
                "You are the Writer agent. You produce clear, structured prose suitable "
                "for a technical-but-busy audience. Use numbered sections and bullets. "
                "Explicitly call out assumptions and limitations."
            ),
        },
        {"role": "user", "content": context},
    ]
    text, meta = call_llm(messages, model=MODEL_ID, temperature=0.25)
    log_agent_run(use_case, "Writer", "draft", meta)
    return text


def critic_agent(draft: str, use_case: str, focus: str = "coverage, logic, and evidence") -> str:
    messages = [
        {
            "role": "system",
            "content": ("You are the Critic agent. You provide actionable edits only: "
                "missing coverage, weak logic, and evidence gaps. Use bullets. "
                "Do NOT rewrite the full piece."
            ),
        },
        {
            "role": "user",
            "content": f"Critique the following draft with emphasis on {focus}: n\n" + draft,
        },
    ]
    text, meta = call_llm(messages, model=MODEL_ID, temperature=0.1, max_tokens=500)
    log_agent_run(use_case, "Critic", "review", meta)
    return text


def judge_text(text: str, use_case: str, label: str) -> Dict[str, Any]:
    """Judge returns strict JSON: coverage, coherence, citations, factuality, future_alignment, notes."""
    sys = (
        "You are the Judge agent for an agentic AI evaluation. "
        "Return STRICT JSON ONLY with keys:\n"
        "  coverage (0-1), coherence (0-1), citations (0-1), factuality (0-1), "
        "  future_alignment (0-1), notes (string).\n"
        "No extra commentary."
    )
    messages = [
        {"role": "system", "content": sys},
        {
            "role": "user",
            "content": (
                "Evaluate the following output over the rubric and respond with strict JSON only:\n\n"
                + text
            ),
        },
    ]
    raw, meta = call_llm(messages, model=MODEL_ID, temperature=0.0, max_tokens=400)
    log_agent_run(use_case, "Judge", f"eval_{label}", meta)
    try:
        obj = json.loads(raw)
    except Exception:
        obj = {
            "coverage": 0.0,
            "coherence": 0.0,
            "citations": 0.0,
            "factuality": 0.0,
            "future_alignment": 0.0,
            "notes": f"Parse error from Judge: {raw[:120]}...",
        }
    show_json(obj, f"{use_case} — Judge JSON ({label})")
    return obj


def coverage_badge(judge: Dict[str, Any], label: str):
    cov = float(judge.get("coverage", 0.0))
    kind = "success" if cov >= 0.8 else ("warn" if cov >= 0.6 else "fail")
    show_badge(f"{label} Coverage: {cov:.2f}", kind=kind)

# %% [markdown]
# ## UC1 — Hybrid Orchestration (Researcher → Writer → Critic)
#
# ### **Why now? What is an agent?**
# **Goal:** Show a simple **plan → act → reflect** loop using three distinct roles.
#
# We generate a **research brief** on **Hybrid Orchestration** for agentic systems.
#
# 👉 **Run the cell below** once your GL key is set.

# %%
def run_uc1():
    use_case = "UC1"
    topic = (
        "Write a research brief on 'Hybrid Orchestration for Agentic Systems' with ~8 short sections:\n"
        "1) Definition & motivation\n"
        "2) When hybrid beats centralized or peer-only\n"
        "3) Latency, reliability, failure containment\n"
        "4) Budget-aware routing & tool use\n"
        "5) Observability & minimal state\n"
        "6) Security & policy shields\n"
        "7) Short vignette (enterprise example)\n"
        "8) References & assumptions\n"
        "Outline first; then draft; then critique."
    )

    outline = researcher_agent(topic, use_case)
    draft = writer_agent(
        "Use the following outline/evidence to write the brief:\n\n" + outline,
        use_case,
    )
    critique = critic_agent(draft, use_case)

    final_text = (
        draft
        + "\n\n---\nCritic suggestions (apply separately):\n"
        + critique
    )
    show_card("UC1 — Hybrid Orchestration Brief (Draft + Critique)", final_text, kind="info")

    judge = judge_text(final_text, use_case, label="hybrid_orchestration")
    coverage_badge(judge, "UC1")
    show_run_summary(use_case)


# Run UC1
run_uc1()
# Out:
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC1 · Researcher (analysis/outline) — 561 tok, 8.84s, $0.0003
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC1 · Writer (draft) — 1272 tok, 15.46s, $0.0006
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC1 · Critic (review) — 1111 tok, 4.58s, $0.0003
#     </span>
#     <div style="border-radius:12px;padding:12px 14px;margin:10px 0;
#                 border:1px solid #0ea5e9;background:#f0f9ff;">
#       <div style="font-weight:700;color:#0ea5e9;margin-bottom:4px;">UC1 — Hybrid Orchestration Brief (Draft + Critique)</div>
#       <div style="white-space:pre-wrap;line-height:1.4;font-size:14px;"># Research Brief on Hybrid Orchestration for Agentic Systems
#
# ## 1. Definition & Motivation
# - **Definition**: Hybrid orchestration refers to a model that combines centralized and decentralized approaches to manage interactions among autonomous agents in agentic systems. It leverages the strengths of both methods to optimize performance and adaptability.
# - **Importance of Orchestration**: In multi-agent systems, orchestration is crucial for coordinating actions, ensuring efficient communication, and achieving collective goals. Effective orchestration enhances collaboration and resource utilization among agents.
# - **Motivation for Hybrid Approaches**: Traditional centralized models can become bottlenecks, while purely decentralized systems may lack coordination. Hybrid approaches aim to overcome these limitations by providing a balance that enhances flexibility and responsiveness.
#
# ## 2. When Hybrid Beats Centralized or Peer-Only
# - **Comparison of Models**:
#   - **Centralized**: Single point of control; can lead to bottlenecks.
#   - **Peer-Only**: No central authority; may struggle with coordination.
#   - **Hybrid**: Combines both, allowing for centralized decision-making when necessary and decentralized execution.
# - **Advantages of Hybrid Orchestration**:
#   - **Flexibility**: Adapts to varying operational conditions and agent capabilities.
#   - **Scalability**: Efficiently manages an increasing number of agents without significant performance degradation.
#   - **Adaptability**: Quickly responds to changes in the environment or agent behavior.
#
# ## 3. Latency, Reliability, Failure Containment
# - **Impact on Latency**: Hybrid orchestration can reduce latency by allowing agents to communicate directly when appropriate, minimizing delays associated with centralized processing.
# - **Reliability Improvements**: Distributed decision-making enhances reliability, as the failure of one agent does not compromise the entire system. Redundant pathways for communication can be established.
# - **Failure Containment Mechanisms**: Hybrid systems can implement strategies such as local recovery protocols and fallback procedures to isolate and manage failures without affecting overall system performance.
#
# ## 4. Budget-Aware Routing & Tool Use
# - **Budget-Aware Routing**: This concept involves optimizing the routing of tasks and communications based on resource constraints, ensuring that agents operate within defined budget limits.
# - **Resource Optimization**: Agents can assess their available resources and select tools or methods that maximize efficiency while adhering to budgetary constraints.
# - **Examples**: In scenarios where computational resources are limited, agents may prioritize simpler algorithms or delegate tasks to more capable peers to stay within budget.
#
# ## 5. Observability & Minimal State
# - **Observability Defined**: In hybrid orchestration, observability refers to the ability to monitor and understand the state and actions of agents within the system.
# - **Importance of Minimal State**: Maintaining a minimal state reduces overhead and enhances performance. It allows agents to operate efficiently without retaining excessive historical data.
# - **Enhancing Observability**: Techniques such as event logging and state summarization can improve visibility into agent actions while keeping the state lightweight.
#
# ## 6. Security & Policy Shields
# - **Security Challenges**: Hybrid orchestration introduces vulnerabilities due to the combination of centralized and decentralized elements, making it crucial to address potential security risks.
# - **Role of Policy Shields**: Policy shields act as protective layers that enforce security protocols and ensure safe interactions among agents, mitigating risks associated with unauthorized access or data breaches.
# - **Implementation Strategies**: Security measures can include encryption, authentication protocols, and regular audits to ensure compliance with established policies.
#
# ## 7. Short Vignette (Enterprise Example)
# - **Case Study**: An enterprise in the logistics sector implemented hybrid orchestration to manage its fleet of delivery drones.
# - **Challenges Faced**: The company struggled with coordinating multiple drones in real-time while optimizing delivery routes and minimizing operational costs.
# - **Solutions Implemented**: By adopting a hybrid orchestration model, the enterprise enabled drones to communicate directly for route adjustments while maintaining a centralized system for
#
# ---
# Critic suggestions (apply separately):
# - **Coverage Gaps**:
#   - Expand on the specific types of agentic systems that benefit from hybrid orchestration. Are there particular domains (e.g., healthcare, manufacturing) where this model is especially effective?
#   - Include a section on potential drawbacks or limitations of hybrid orchestration to provide a balanced view.
#   - Provide more detailed examples or case studies beyond the logistics sector to illustrate the versatility of hybrid orchestration in different contexts.
#
# - **Weak Logic**:
#   - Clarify the reasoning behind why hybrid orchestration specifically enhances flexibility and adaptability compared to purely centralized or decentralized systems. What mechanisms enable this?
#   - The section on "Budget-Aware Routing" could benefit from a clearer connection to how it specifically relates to hybrid orchestration. Why is this concept particularly relevant in a hybrid context?
#
# - **Evidence Gaps**:
#   - Include empirical data or references to studies that demonstrate the effectiveness of hybrid orchestration in real-world applications. This would strengthen claims about its advantages.
#   - Provide quantitative metrics or examples of performance improvements (e.g., reduced latency, increased reliability) observed in hybrid orchestration implementations.
#   - Cite specific security incidents or vulnerabilities that have arisen in hybrid orchestration systems to substantiate claims about security challenges.</div>
#     </div>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC1 · Judge (eval_hybrid_orchestration) — 1243 tok, 1.75s, $0.0002
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC1 — Judge JSON (hybrid_orchestration)</div>
# <pre style='background:#020617;color:#e5e7eb;padding:10px;border-radius:8px;font-size:12px;'>{   "coverage": 0.6,   "coherence": 0.7,   "citations": 0.0,   "factuality": 0.8,   "future_alignment": 0.5,   "notes": "The output provides a solid
#
#  overview of hybrid orchestration but lacks coverage on specific domains and potential drawbacks. Logic could be strengthened with clearer
#
#  connections and examples. There are no citations or empirical evidence to support claims." }</pre>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#f59e0b;background:#fffbeb;
#                  margin:4px 0;">
#       UC1 Coverage: 0.60
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC1 — Cost/Latency Summary</div>
# <style type="text/css">
# #T_efce8 th {
#   background-color: #e5e7eb;
# }
# </style>
# <table id="T_efce8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efce8_level0_col0" class="col_heading level0 col0" >Agent</th>
#       <th id="T_efce8_level0_col1" class="col_heading level0 col1" >Role</th>
#       <th id="T_efce8_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_efce8_level0_col3" class="col_heading level0 col3" >Prompt tok</th>
#       <th id="T_efce8_level0_col4" class="col_heading level0 col4" >Completion tok</th>
#       <th id="T_efce8_level0_col5" class="col_heading level0 col5" >Total tok</th>
#       <th id="T_efce8_level0_col6" class="col_heading level0 col6" >Latency (s)</th>
#       <th id="T_efce8_level0_col7" class="col_heading level0 col7" >Cost (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efce8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efce8_row0_col0" class="data row0 col0" >Researcher</td>
#       <td id="T_efce8_row0_col1" class="data row0 col1" >analysis/outline</td>
#       <td id="T_efce8_row0_col2" class="data row0 col2" >gpt-4o-mini</td>
#       <td id="T_efce8_row0_col3" class="data row0 col3" >146</td>
#       <td id="T_efce8_row0_col4" class="data row0 col4" >415</td>
#       <td id="T_efce8_row0_col5" class="data row0 col5" >561</td>
#       <td id="T_efce8_row0_col6" class="data row0 col6" >8.840000</td>
#       <td id="T_efce8_row0_col7" class="data row0 col7" >0.000271</td>
#     </tr>
#     <tr>
#       <th id="T_efce8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efce8_row1_col0" class="data row1 col0" >Writer</td>
#       <td id="T_efce8_row1_col1" class="data row1 col1" >draft</td>
#       <td id="T_efce8_row1_col2" class="data row1 col2" >gpt-4o-mini</td>
#       <td id="T_efce8_row1_col3" class="data row1 col3" >472</td>
#       <td id="T_efce8_row1_col4" class="data row1 col4" >800</td>
#       <td id="T_efce8_row1_col5" class="data row1 col5" >1272</td>
#       <td id="T_efce8_row1_col6" class="data row1 col6" >15.460000</td>
#       <td id="T_efce8_row1_col7" class="data row1 col7" >0.000551</td>
#     </tr>
#     <tr>
#       <th id="T_efce8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efce8_row2_col0" class="data row2 col0" >Critic</td>
#       <td id="T_efce8_row2_col1" class="data row2 col1" >review</td>
#       <td id="T_efce8_row2_col2" class="data row2 col2" >gpt-4o-mini</td>
#       <td id="T_efce8_row2_col3" class="data row2 col3" >861</td>
#       <td id="T_efce8_row2_col4" class="data row2 col4" >250</td>
#       <td id="T_efce8_row2_col5" class="data row2 col5" >1111</td>
#       <td id="T_efce8_row2_col6" class="data row2 col6" >4.580000</td>
#       <td id="T_efce8_row2_col7" class="data row2 col7" >0.000279</td>
#     </tr>
#     <tr>
#       <th id="T_efce8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efce8_row3_col0" class="data row3 col0" >Judge</td>
#       <td id="T_efce8_row3_col1" class="data row3 col1" >eval_hybrid_orchestration</td>
#       <td id="T_efce8_row3_col2" class="data row3 col2" >gpt-4o-mini</td>
#       <td id="T_efce8_row3_col3" class="data row3 col3" >1145</td>
#       <td id="T_efce8_row3_col4" class="data row3 col4" >98</td>
#       <td id="T_efce8_row3_col5" class="data row3 col5" >1243</td>
#       <td id="T_efce8_row3_col6" class="data row3 col6" >1.750000</td>
#       <td id="T_efce8_row3_col7" class="data row3 col7" >0.000231</td>
#     </tr>
#     <tr>
#       <th id="T_efce8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_efce8_row4_col0" class="data row4 col0" >TOTAL</td>
#       <td id="T_efce8_row4_col1" class="data row4 col1" >—</td>
#       <td id="T_efce8_row4_col2" class="data row4 col2" >—</td>
#       <td id="T_efce8_row4_col3" class="data row4 col3" >2624</td>
#       <td id="T_efce8_row4_col4" class="data row4 col4" >1563</td>
#       <td id="T_efce8_row4_col5" class="data row4 col5" >4187</td>
#       <td id="T_efce8_row4_col6" class="data row4 col6" >30.630000</td>
#       <td id="T_efce8_row4_col7" class="data row4 col7" >0.001332</td>
#     </tr>
#   </tbody>
# </table>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#16a34a;background:#ecfdf5;
#                  margin:4px 0;">
#       UC1 Budget: $0.0013
#     </span>

# %% [markdown]
# ## UC2 — Operating Modes & LOA-A Promotion
#
# ### **Operating modes (HITL, Human-on-the-loop, Autonomous) & LOA-A scale**
# **Goal:** Show how **Impact × Reversibility** drives mode selection and **promotion criteria**.
#
# We feed a scenario and ask the agents to:
# - pick an operating mode,
# - justify the choice,
# - and argue whether it is ready for promotion.
#
# 👉 **Run the cell below** after UC1 completes.

# %%
def run_uc2():
    use_case = "UC2"
    scenario_desc = (
        "Scenario: An internal agent generates monthly ETL reports from stable warehouse tables, "
        "aggregating metrics and emailing a draft dashboard to analysts. "
        "Impact: Medium; errors are reversible (humans review before decisions). "
        "Goal: Decide whether this workflow should be HITL, Human-on-the-loop, or Autonomous, "
        "and whether it might be promoted over time.\n\n"
        "1) Choose the operating mode and LOA-A level.\n"
        "2) Map Impact × Reversibility to that choice.\n"
        "3) Describe guardrails-as-code (tool allowlist, budget caps, alerts).\n"
        "4) Explain promotion criteria to a higher autonomy level."
    )

    outline = researcher_agent(
        "Decompose the analysis for this scenario and outline the argument:\n\n" + scenario_desc,
        use_case,
    )
    draft = writer_agent(
        "Using this outline, write a concise decision note (~1 page):\n\n" + outline,
        use_case,
    )
    critique = critic_agent(
        draft,
        use_case,
        focus=(
            "linkages between impact, reversibility, LOA-A, guardrails-as-code, and promotion criteria"
        ),
    )

    final_text = draft + "\n\n---\nCritic suggestions (apply separately):\n" + critique
    show_card("UC2 — Operating Mode Decision Note", final_text, kind="info")

    judge = judge_text(final_text, use_case, label="mode_and_loa")
    coverage_badge(judge, "UC2")
    show_run_summary(use_case)


# Run UC2
run_uc2()
# Out:
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC2 · Researcher (analysis/outline) — 651 tok, 6.72s, $0.0003
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC2 · Writer (draft) — 1327 tok, 20.07s, $0.0006
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC2 · Critic (review) — 1148 tok, 5.95s, $0.0003
#     </span>
#     <div style="border-radius:12px;padding:12px 14px;margin:10px 0;
#                 border:1px solid #0ea5e9;background:#f0f9ff;">
#       <div style="font-weight:700;color:#0ea5e9;margin-bottom:4px;">UC2 — Operating Mode Decision Note</div>
#       <div style="white-space:pre-wrap;line-height:1.4;font-size:14px;"># Decision Note: Analysis of ETL Report Workflow
#
# ## I. Introduction
# The Extract, Transform, Load (ETL) report generation process is critical for data integration and analysis within our organization. Determining the appropriate operating mode and level of autonomy (LOA-A) is essential to enhance efficiency, accuracy, and responsiveness in our data workflows.
#
# ## II. Operating Mode and Level of Autonomy (LOA-A)
#
# ### A. Definition of Operating Modes
# - **Human-in-the-Loop (HITL)**: Human intervention is required at every stage of the process.
# - **Human-on-the-Loop (HOTL)**: Humans oversee the process but do not engage in every operation.
# - **Autonomous**: The process operates independently with minimal human oversight.
#
# ### B. Recommended Operating Mode
# - **Chosen Mode**: Human-on-the-Loop (HOTL)
# - **Justification**: This mode balances efficiency and oversight, allowing for timely interventions while leveraging automation to reduce manual workload.
#
# ### C. Level of Autonomy (LOA-A)
# - **Explanation**: LOA-A levels range from fully manual (LOA-A1) to fully autonomous (LOA-A5).
# - **Selected Level**: LOA-A3 (Moderate Autonomy) is appropriate, allowing for automated processes with human oversight for critical decision points.
#
# ## III. Impact and Reversibility Analysis
#
# ### A. Mapping Impact to Operating Mode
# - **Impact Definition**: Medium impact, indicating moderate risk associated with errors in the ETL process.
# - **Influence on Mode Choice**: Medium impact necessitates a balance between automation and human oversight, supporting the HOTL mode.
#
# ### B. Reversibility of Errors
# - **Explanation**: Errors can be corrected through human review, which is essential in a medium-impact scenario.
# - **Support for Chosen Mode**: The ability to reverse errors reinforces the decision to adopt HOTL and LOA-A3, ensuring that human intervention can mitigate potential issues.
#
# ## IV. Guardrails-as-Code
#
# ### A. Definition and Importance
# - **Explanation**: Guardrails-as-code establishes automated guidelines to ensure compliance and reduce errors in ETL processes.
#
# ### B. Tool Allowlist
# - **Identification**: A curated list of approved tools will be maintained to streamline the ETL process and ensure compatibility.
#
# ### C. Budget Caps
# - **Establishment**: Budget limits will be set to control costs associated with the ETL process, ensuring financial accountability.
#
# ### D. Alerts
# - **Description**: Alert mechanisms will be implemented to monitor the ETL workflow and detect errors in real-time, facilitating prompt corrective actions.
#
# ## V. Promotion Criteria for Higher Autonomy Level
#
# ### A. Definition of Promotion Criteria
# - **Explanation**: Successful transition to a higher autonomy level is based on consistent performance and error reduction.
#
# ### B. Performance Metrics
# - **KPIs**: Key performance indicators will include error rates, processing times, and user satisfaction scores.
#
# ### C. Review Process
# - **Outline**: A structured review process will assess the workflow's readiness for promotion, involving periodic evaluations against established metrics.
#
# ### D. Stakeholder Involvement
# - **Importance**: Continuous feedback from analysts and stakeholders is crucial for informed decision-making regarding autonomy levels.
#
# ## VI. Conclusion
# In summary, the recommended operating mode is Human-on-the-Loop (HOTL) with a Level of Autonomy (LOA-A3). This approach effectively balances efficiency and oversight, accommodating the medium impact of the ETL process. The implementation of guardrails-as-code, along with defined promotion criteria, will facilitate the potential for increased autonomy in the future. Continued stakeholder engagement will be vital to adapt and refine the ETL report workflow as we move forward.
#
# ### Assumptions and Limitations
# - This analysis assumes that current tools and resources are sufficient to support the recommended operating mode.
# - The effectiveness of the HOT
#
# ---
# Critic suggestions (apply separately):
# - **Linkages Between Impact and Reversibility**: Clarify how the medium impact directly influences the choice of HOTL and LOA-A3. Provide specific examples of potential errors and their consequences to strengthen this connection.
#
# - **Evidence Gaps in Reversibility**: Expand on the mechanisms for error correction. What specific processes or tools will be used for human review? Include examples of past scenarios where human intervention successfully mitigated errors.
#
# - **Guardrails-as-Code Implementation**: Provide more detail on how guardrails-as-code will be implemented. What specific guidelines will be automated, and how will they be enforced? Include examples of potential compliance issues that could arise without these guardrails.
#
# - **Promotion Criteria Clarity**: Elaborate on the specific thresholds for the KPIs mentioned. What constitutes "consistent performance" and "error reduction"? Define the metrics more clearly to avoid ambiguity.
#
# - **Stakeholder Involvement**: Discuss how stakeholder feedback will be collected and integrated into the decision-making process. What methods will be used to ensure that feedback is actionable and leads to tangible changes?
#
# - **Assumptions and Limitations**: Expand on the limitations of the current tools and resources. What specific gaps exist that could hinder the implementation of HOTL and LOA-A3? How might these limitations affect the overall effectiveness of the ETL process?</div>
#     </div>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC2 · Judge (eval_mode_and_loa) — 1296 tok, 2.82s, $0.0003
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC2 — Judge JSON (mode_and_loa)</div>
# <pre style='background:#020617;color:#e5e7eb;padding:10px;border-radius:8px;font-size:12px;'>{   "coverage": 0.7,   "coherence": 0.8,   "citations": 0,   "factuality": 1,   "future_alignment": 0.6,   "notes": "The analysis provides a solid
#
#  overview of the ETL report workflow and the recommended operating mode. However, it lacks specific examples and detailed explanations in several
#
#  areas, such as the linkages between impact and reversibility, mechanisms for error correction, implementation of guardrails-as-code, and clarity on
#
#  promotion criteria. Addressing these gaps would enhance the overall robustness and applicability of the recommendations." }</pre>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#f59e0b;background:#fffbeb;
#                  margin:4px 0;">
#       UC2 Coverage: 0.70
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC2 — Cost/Latency Summary</div>
# <style type="text/css">
# #T_51ba5 th {
#   background-color: #e5e7eb;
# }
# </style>
# <table id="T_51ba5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51ba5_level0_col0" class="col_heading level0 col0" >Agent</th>
#       <th id="T_51ba5_level0_col1" class="col_heading level0 col1" >Role</th>
#       <th id="T_51ba5_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_51ba5_level0_col3" class="col_heading level0 col3" >Prompt tok</th>
#       <th id="T_51ba5_level0_col4" class="col_heading level0 col4" >Completion tok</th>
#       <th id="T_51ba5_level0_col5" class="col_heading level0 col5" >Total tok</th>
#       <th id="T_51ba5_level0_col6" class="col_heading level0 col6" >Latency (s)</th>
#       <th id="T_51ba5_level0_col7" class="col_heading level0 col7" >Cost (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51ba5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51ba5_row0_col0" class="data row0 col0" >Researcher</td>
#       <td id="T_51ba5_row0_col1" class="data row0 col1" >analysis/outline</td>
#       <td id="T_51ba5_row0_col2" class="data row0 col2" >gpt-4o-mini</td>
#       <td id="T_51ba5_row0_col3" class="data row0 col3" >183</td>
#       <td id="T_51ba5_row0_col4" class="data row0 col4" >468</td>
#       <td id="T_51ba5_row0_col5" class="data row0 col5" >651</td>
#       <td id="T_51ba5_row0_col6" class="data row0 col6" >6.720000</td>
#       <td id="T_51ba5_row0_col7" class="data row0 col7" >0.000308</td>
#     </tr>
#     <tr>
#       <th id="T_51ba5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51ba5_row1_col0" class="data row1 col0" >Writer</td>
#       <td id="T_51ba5_row1_col1" class="data row1 col1" >draft</td>
#       <td id="T_51ba5_row1_col2" class="data row1 col2" >gpt-4o-mini</td>
#       <td id="T_51ba5_row1_col3" class="data row1 col3" >527</td>
#       <td id="T_51ba5_row1_col4" class="data row1 col4" >800</td>
#       <td id="T_51ba5_row1_col5" class="data row1 col5" >1327</td>
#       <td id="T_51ba5_row1_col6" class="data row1 col6" >20.070000</td>
#       <td id="T_51ba5_row1_col7" class="data row1 col7" >0.000559</td>
#     </tr>
#     <tr>
#       <th id="T_51ba5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51ba5_row2_col0" class="data row2 col0" >Critic</td>
#       <td id="T_51ba5_row2_col1" class="data row2 col1" >review</td>
#       <td id="T_51ba5_row2_col2" class="data row2 col2" >gpt-4o-mini</td>
#       <td id="T_51ba5_row2_col3" class="data row2 col3" >875</td>
#       <td id="T_51ba5_row2_col4" class="data row2 col4" >273</td>
#       <td id="T_51ba5_row2_col5" class="data row2 col5" >1148</td>
#       <td id="T_51ba5_row2_col6" class="data row2 col6" >5.950000</td>
#       <td id="T_51ba5_row2_col7" class="data row2 col7" >0.000295</td>
#     </tr>
#     <tr>
#       <th id="T_51ba5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51ba5_row3_col0" class="data row3 col0" >Judge</td>
#       <td id="T_51ba5_row3_col1" class="data row3 col1" >eval_mode_and_loa</td>
#       <td id="T_51ba5_row3_col2" class="data row3 col2" >gpt-4o-mini</td>
#       <td id="T_51ba5_row3_col3" class="data row3 col3" >1168</td>
#       <td id="T_51ba5_row3_col4" class="data row3 col4" >128</td>
#       <td id="T_51ba5_row3_col5" class="data row3 col5" >1296</td>
#       <td id="T_51ba5_row3_col6" class="data row3 col6" >2.820000</td>
#       <td id="T_51ba5_row3_col7" class="data row3 col7" >0.000252</td>
#     </tr>
#     <tr>
#       <th id="T_51ba5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_51ba5_row4_col0" class="data row4 col0" >TOTAL</td>
#       <td id="T_51ba5_row4_col1" class="data row4 col1" >—</td>
#       <td id="T_51ba5_row4_col2" class="data row4 col2" >—</td>
#       <td id="T_51ba5_row4_col3" class="data row4 col3" >2753</td>
#       <td id="T_51ba5_row4_col4" class="data row4 col4" >1669</td>
#       <td id="T_51ba5_row4_col5" class="data row4 col5" >4422</td>
#       <td id="T_51ba5_row4_col6" class="data row4 col6" >35.560000</td>
#       <td id="T_51ba5_row4_col7" class="data row4 col7" >0.001414</td>
#     </tr>
#   </tbody>
# </table>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#16a34a;background:#ecfdf5;
#                  margin:4px 0;">
#       UC2 Budget: $0.0014
#     </span>

# %% [markdown]
# ## UC3 — Truth Tests & Future-Scan
#
# ### **Truth tests for agentic claims**
# **Goal:** Demonstrate that:
#
# - Adding planning and reflection can **change outcomes**.
# - We can analyze answers for **meta-signals** like reasoning depth and future-alignment.
#
# We run three conditions on the same question:
#
# 1. **Baseline** — outline then answer with reflection hints.
# 2. **No-planning** — answer directly, no outline.
# 3. **No-reflection** — outline but discourage critique/self-correction.
#
# We then apply a **Future Scan** meta-agent that returns heuristic scores for:
# - `reasoning_depth`, `reflection_evidence`, `delegation_pattern`, `future_alignment`.
#
# 👉 **Run the cell below** after UC2.

# %%
def future_scan_agent(answer: str, use_case: str, label: str) -> Dict[str, Any]:
    """Meta-evaluator for reasoning & future alignment (LLM-based, heuristic)."""
    sys = (
        "You are a meta-evaluator of agentic reasoning. Given an answer, rate:\n"
        "- reasoning_depth (0-1)\n"
        "- reflection_evidence (0-1)\n"
        "- delegation_pattern (0-1)  # hints of multi-agent thinking\n"
        "- future_alignment (0-1)    # how well it anticipates the next decade of agentic AI\n\n"
        "Return STRICT JSON ONLY with those keys plus 'notes'."
    )
    messages = [
        {"role": "system", "content": sys},
        {"role": "user", "content": "Analyze this answer:\n\n" + answer},
    ]
    raw, meta = call_llm(messages, model=MODEL_ID, temperature=0.0, max_tokens=400)
    log_agent_run(use_case, "FutureScan", label, meta)
    try:
        obj = json.loads(raw)
    except Exception:
        obj = {
            "reasoning_depth": 0.0,
            "reflection_evidence": 0.0,
            "delegation_pattern": 0.0,
            "future_alignment": 0.0,
            "notes": f"Parse error from FutureScan: {raw[:120]}...",
        }
    return obj


def run_uc3():
    use_case = "UC3"
    task = (
        "Explain why observability (traces, replay, cost/latency metrics) is critical for agentic AI deployments. "
        "Focus on concrete mechanisms: debugging, governance, promotion/demotion of autonomy, and incident response."
        "Give citations to support your claims."
    )

    variants = []

    # Baseline: planning + reflection
    baseline_prompt = (
        "First outline 4–6 steps, then write a short explanation. "
        "Include at least one example of how logs changed a deployment decision."
        "Please carefully consider your answer by first doing detailed planning and then reflecting on the result."
    )
    ans_baseline = writer_agent(baseline_prompt + "\n\nTask:\n" + task, use_case)
    judge_baseline = judge_text(ans_baseline, use_case, label="baseline")
    scan_baseline = future_scan_agent(ans_baseline, use_case, label="baseline_scan")
    variants.append(("Baseline", ans_baseline, judge_baseline, scan_baseline))

    # No-planning: answer directly
    noplan_prompt = (
        "Answer directly in one pass without outlining or explicit planning steps. "
        "Do not make or list a plan; just give the explanation."
    )
    ans_noplan = writer_agent(noplan_prompt + "\n\nTask:\n" + task, use_case)
    judge_noplan = judge_text(ans_noplan, use_case, label="no_plan")
    scan_noplan = future_scan_agent(ans_noplan, use_case, label="no_plan_scan")
    variants.append(("No-Planning", ans_noplan, judge_noplan, scan_noplan))

    # No-reflection: outline but discourage revision
    norefl_prompt = (
        "Outline briefly, then answer, but do not critique or revise your own answer. "
        "Avoid hedging or self-correction and get right to the point."
    )
    ans_norefl = writer_agent(norefl_prompt + "\n\nTask:\n" + task, use_case)
    judge_norefl = judge_text(ans_norefl, use_case, label="no_reflection")
    scan_norefl = future_scan_agent(ans_norefl, use_case, label="no_reflection_scan")
    variants.append(("No-Reflection", ans_norefl, judge_norefl, scan_norefl))

    # Show baseline answer for class discussion
    show_card("UC3 — Baseline Answer (Plan + Reflection)", variants[0][1], kind="info")

    # Build summary table
    rows = []
    for name, _, j, s in variants:
        rows.append(
            {
                "Variant": name,
                "Coverage": round(float(j.get("coverage", 0.0)), 2),
                "Coherence": round(float(j.get("coherence", 0.0)), 2),
                "Citations": round(float(j.get("citations", 0.0)), 2),
                "Factuality": round(float(j.get("factuality", 0.0)), 2),
                "FutureAlign (judge)": round(float(j.get("future_alignment", 0.0)), 2),
                "ReasoningDepth": round(float(s.get("reasoning_depth", 0.0)), 2),
                "ReflectionEvidence": round(float(s.get("reflection_evidence", 0.0)), 2),
            }
        )
    df = pd.DataFrame(rows)
    show_table(df, "UC3 — Truth Test Summary")

    show_run_summary(use_case)


# Run UC3
run_uc3()
# Out:
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · Writer (draft) — 941 tok, 16.55s, $0.0005
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · Judge (eval_baseline) — 969 tok, 2.07s, $0.0002
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC3 — Judge JSON (baseline)</div>
# <pre style='background:#020617;color:#e5e7eb;padding:10px;border-radius:8px;font-size:12px;'>{   "coverage": 1,   "coherence": 1,   "citations": 1,   "factuality": 1,   "future_alignment": 1,   "notes": "The output provides a comprehensive
#
#  outline and detailed explanation of observability in AI, covering all relevant aspects and including a citation. It is coherent and aligns with
#
#  future AI system design considerations." }</pre>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · FutureScan (baseline_scan) — 1004 tok, 2.70s, $0.0002
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · Writer (draft) — 582 tok, 8.72s, $0.0003
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · Judge (eval_no_plan) — 631 tok, 2.52s, $0.0001
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC3 — Judge JSON (no_plan)</div>
# <pre style='background:#020617;color:#e5e7eb;padding:10px;border-radius:8px;font-size:12px;'>{   "coverage": 1,   "coherence": 1,   "citations": 1,   "factuality": 1,   "future_alignment": 1,   "notes": "The output thoroughly covers the topic
#
#  of observability in agentic AI, providing coherent arguments supported by relevant citations. All claims are factually accurate and align with
#
#  future considerations for AI governance and reliability." }</pre>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · FutureScan (no_plan_scan) — 661 tok, 1.93s, $0.0001
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · Writer (draft) — 608 tok, 13.82s, $0.0003
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · Judge (eval_no_reflection) — 636 tok, 1.63s, $0.0001
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC3 — Judge JSON (no_reflection)</div>
# <pre style='background:#020617;color:#e5e7eb;padding:10px;border-radius:8px;font-size:12px;'>{   "coverage": 1,   "coherence": 1,   "citations": 1,   "factuality": 1,   "future_alignment": 1,   "notes": "The output provides a comprehensive
#
#  outline and explanation of observability in AI, covering key aspects and mechanisms with appropriate citations." }</pre>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC3 · FutureScan (no_reflection_scan) — 702 tok, 2.74s, $0.0002
#     </span>
#     <div style="border-radius:12px;padding:12px 14px;margin:10px 0;
#                 border:1px solid #0ea5e9;background:#f0f9ff;">
#       <div style="font-weight:700;color:#0ea5e9;margin-bottom:4px;">UC3 — Baseline Answer (Plan + Reflection)</div>
#       <div style="white-space:pre-wrap;line-height:1.4;font-size:14px;">### Outline of Steps
#
# 1. **Define Observability in AI Context**
#    - Explain the components of observability: traces, replay, and cost/latency metrics.
#    - Discuss the importance of these components in understanding AI behavior.
#
# 2. **Debugging AI Systems**
#    - Describe how observability aids in identifying and resolving issues.
#    - Provide examples of specific debugging scenarios.
#
# 3. **Governance and Compliance**
#    - Explain the role of observability in ensuring compliance with ethical and regulatory standards.
#    - Discuss how logs can inform governance frameworks.
#
# 4. **Promotion and Demotion of Autonomy**
#    - Discuss how observability informs decisions regarding the autonomy levels of AI systems.
#    - Provide examples of criteria used to adjust autonomy based on observed performance.
#
# 5. **Incident Response**
#    - Explain how observability facilitates rapid incident response.
#    - Discuss the importance of real-time metrics in mitigating risks.
#
# 6. **Conclusion**
#    - Summarize the critical role of observability in agentic AI deployments.
#    - Highlight the implications for future AI system design and deployment.
#
# ### Explanation
#
# #### 1. Define Observability in AI Context
# Observability in the context of agentic AI refers to the ability to monitor and understand the internal workings and external behaviors of AI systems. Key components include:
# - **Traces**: Detailed logs of system operations and decision-making processes.
# - **Replay**: The ability to recreate past states of the system for analysis.
# - **Cost/Latency Metrics**: Measurements that assess the efficiency and responsiveness of AI operations.
#
# These components are essential for gaining insights into AI behavior, which is critical for effective management and deployment.
#
# #### 2. Debugging AI Systems
# Observability is crucial for debugging AI systems. For example, if an AI model begins to produce unexpected outputs, traces can help developers identify the specific input conditions and decision paths that led to the anomaly. This allows for targeted adjustments rather than broad, potentially disruptive changes.
#
# #### 3. Governance and Compliance
# In an era of increasing regulatory scrutiny, observability provides a framework for ensuring that AI systems adhere to ethical standards. For instance, logs can demonstrate compliance with data privacy regulations by tracking how data is used and processed. This transparency is vital for building trust with stakeholders and regulatory bodies (Binns, 2018).
#
# #### 4. Promotion and Demotion of Autonomy
# Observability informs decisions regarding the level of autonomy granted to AI systems. For example, if an AI system consistently meets performance benchmarks in a controlled environment but fails in real-world applications, the decision may be made to demote its autonomy until further improvements are made. This decision can be based on observed metrics indicating reliability and safety.
#
# #### 5. Incident Response
# In the event of an incident, observability allows for rapid response. Real-time metrics can indicate when an AI system is deviating from expected behavior, enabling teams to intervene before significant damage occurs. For instance, if an autonomous vehicle's sensors report latency issues, immediate action can be taken to prevent accidents.
#
# #### 6. Conclusion
# In summary, observability is critical for agentic AI deployments due to its role in debugging, governance, autonomy management, and incident response. As AI systems become more complex and integrated into society, the need for robust observability mechanisms will only grow, ensuring that these systems operate safely and effectively.
#
# ### Example of Logs Changing a Deployment Decision
# In a case study involving an AI-driven financial trading system, logs revealed that the algorithm was making trades based on outdated market data. This insight led to a decision to implement a more frequent data refresh cycle and to temporarily limit the algorithm's autonomy until the issue was resolved. The logs provided the necessary evidence to justify this change, demonstrating the power of observability in guiding deployment decisions.
#
# ### References
# - Binns, R. (2018). Fairness in Machine Learning: Lessons from Political Philosophy. Proceedings of the 2018 Conference on Fair</div>
#     </div>
# <div style='font-weight:600;margin:6px 0;'>UC3 — Truth Test Summary</div>
# <style type="text/css">
# #T_d1359 th {
#   background-color: #e5e7eb;
# }
# </style>
# <table id="T_d1359" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1359_level0_col0" class="col_heading level0 col0" >Variant</th>
#       <th id="T_d1359_level0_col1" class="col_heading level0 col1" >Coverage</th>
#       <th id="T_d1359_level0_col2" class="col_heading level0 col2" >Coherence</th>
#       <th id="T_d1359_level0_col3" class="col_heading level0 col3" >Citations</th>
#       <th id="T_d1359_level0_col4" class="col_heading level0 col4" >Factuality</th>
#       <th id="T_d1359_level0_col5" class="col_heading level0 col5" >FutureAlign (judge)</th>
#       <th id="T_d1359_level0_col6" class="col_heading level0 col6" >ReasoningDepth</th>
#       <th id="T_d1359_level0_col7" class="col_heading level0 col7" >ReflectionEvidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1359_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d1359_row0_col0" class="data row0 col0" >Baseline</td>
#       <td id="T_d1359_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_d1359_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_d1359_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_d1359_row0_col4" class="data row0 col4" >1.000000</td>
#       <td id="T_d1359_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_d1359_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_d1359_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d1359_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d1359_row1_col0" class="data row1 col0" >No-Planning</td>
#       <td id="T_d1359_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d1359_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_d1359_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_d1359_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_d1359_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_d1359_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_d1359_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d1359_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d1359_row2_col0" class="data row2 col0" >No-Reflection</td>
#       <td id="T_d1359_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_d1359_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d1359_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_d1359_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_d1359_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_d1359_row2_col6" class="data row2 col6" >0.800000</td>
#       <td id="T_d1359_row2_col7" class="data row2 col7" >0.700000</td>
#     </tr>
#   </tbody>
# </table>
# <div style='font-weight:600;margin:6px 0;'>UC3 — Cost/Latency Summary</div>
# <style type="text/css">
# #T_ef32f th {
#   background-color: #e5e7eb;
# }
# </style>
# <table id="T_ef32f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef32f_level0_col0" class="col_heading level0 col0" >Agent</th>
#       <th id="T_ef32f_level0_col1" class="col_heading level0 col1" >Role</th>
#       <th id="T_ef32f_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_ef32f_level0_col3" class="col_heading level0 col3" >Prompt tok</th>
#       <th id="T_ef32f_level0_col4" class="col_heading level0 col4" >Completion tok</th>
#       <th id="T_ef32f_level0_col5" class="col_heading level0 col5" >Total tok</th>
#       <th id="T_ef32f_level0_col6" class="col_heading level0 col6" >Latency (s)</th>
#       <th id="T_ef32f_level0_col7" class="col_heading level0 col7" >Cost (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef32f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef32f_row0_col0" class="data row0 col0" >Writer</td>
#       <td id="T_ef32f_row0_col1" class="data row0 col1" >draft</td>
#       <td id="T_ef32f_row0_col2" class="data row0 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row0_col3" class="data row0 col3" >141</td>
#       <td id="T_ef32f_row0_col4" class="data row0 col4" >800</td>
#       <td id="T_ef32f_row0_col5" class="data row0 col5" >941</td>
#       <td id="T_ef32f_row0_col6" class="data row0 col6" >16.550000</td>
#       <td id="T_ef32f_row0_col7" class="data row0 col7" >0.000501</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef32f_row1_col0" class="data row1 col0" >Judge</td>
#       <td id="T_ef32f_row1_col1" class="data row1 col1" >eval_baseline</td>
#       <td id="T_ef32f_row1_col2" class="data row1 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row1_col3" class="data row1 col3" >886</td>
#       <td id="T_ef32f_row1_col4" class="data row1 col4" >83</td>
#       <td id="T_ef32f_row1_col5" class="data row1 col5" >969</td>
#       <td id="T_ef32f_row1_col6" class="data row1 col6" >2.070000</td>
#       <td id="T_ef32f_row1_col7" class="data row1 col7" >0.000183</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef32f_row2_col0" class="data row2 col0" >FutureScan</td>
#       <td id="T_ef32f_row2_col1" class="data row2 col1" >baseline_scan</td>
#       <td id="T_ef32f_row2_col2" class="data row2 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row2_col3" class="data row2 col3" >899</td>
#       <td id="T_ef32f_row2_col4" class="data row2 col4" >105</td>
#       <td id="T_ef32f_row2_col5" class="data row2 col5" >1004</td>
#       <td id="T_ef32f_row2_col6" class="data row2 col6" >2.700000</td>
#       <td id="T_ef32f_row2_col7" class="data row2 col7" >0.000198</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef32f_row3_col0" class="data row3 col0" >Writer</td>
#       <td id="T_ef32f_row3_col1" class="data row3 col1" >draft</td>
#       <td id="T_ef32f_row3_col2" class="data row3 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row3_col3" class="data row3 col3" >123</td>
#       <td id="T_ef32f_row3_col4" class="data row3 col4" >459</td>
#       <td id="T_ef32f_row3_col5" class="data row3 col5" >582</td>
#       <td id="T_ef32f_row3_col6" class="data row3 col6" >8.720000</td>
#       <td id="T_ef32f_row3_col7" class="data row3 col7" >0.000294</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef32f_row4_col0" class="data row4 col0" >Judge</td>
#       <td id="T_ef32f_row4_col1" class="data row4 col1" >eval_no_plan</td>
#       <td id="T_ef32f_row4_col2" class="data row4 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row4_col3" class="data row4 col3" >545</td>
#       <td id="T_ef32f_row4_col4" class="data row4 col4" >86</td>
#       <td id="T_ef32f_row4_col5" class="data row4 col5" >631</td>
#       <td id="T_ef32f_row4_col6" class="data row4 col6" >2.520000</td>
#       <td id="T_ef32f_row4_col7" class="data row4 col7" >0.000133</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ef32f_row5_col0" class="data row5 col0" >FutureScan</td>
#       <td id="T_ef32f_row5_col1" class="data row5 col1" >no_plan_scan</td>
#       <td id="T_ef32f_row5_col2" class="data row5 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row5_col3" class="data row5 col3" >558</td>
#       <td id="T_ef32f_row5_col4" class="data row5 col4" >103</td>
#       <td id="T_ef32f_row5_col5" class="data row5 col5" >661</td>
#       <td id="T_ef32f_row5_col6" class="data row5 col6" >1.930000</td>
#       <td id="T_ef32f_row5_col7" class="data row5 col7" >0.000146</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ef32f_row6_col0" class="data row6 col0" >Writer</td>
#       <td id="T_ef32f_row6_col1" class="data row6 col1" >draft</td>
#       <td id="T_ef32f_row6_col2" class="data row6 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row6_col3" class="data row6 col3" >128</td>
#       <td id="T_ef32f_row6_col4" class="data row6 col4" >480</td>
#       <td id="T_ef32f_row6_col5" class="data row6 col5" >608</td>
#       <td id="T_ef32f_row6_col6" class="data row6 col6" >13.820000</td>
#       <td id="T_ef32f_row6_col7" class="data row6 col7" >0.000307</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ef32f_row7_col0" class="data row7 col0" >Judge</td>
#       <td id="T_ef32f_row7_col1" class="data row7 col1" >eval_no_reflection</td>
#       <td id="T_ef32f_row7_col2" class="data row7 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row7_col3" class="data row7 col3" >566</td>
#       <td id="T_ef32f_row7_col4" class="data row7 col4" >70</td>
#       <td id="T_ef32f_row7_col5" class="data row7 col5" >636</td>
#       <td id="T_ef32f_row7_col6" class="data row7 col6" >1.630000</td>
#       <td id="T_ef32f_row7_col7" class="data row7 col7" >0.000127</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ef32f_row8_col0" class="data row8 col0" >FutureScan</td>
#       <td id="T_ef32f_row8_col1" class="data row8 col1" >no_reflection_scan</td>
#       <td id="T_ef32f_row8_col2" class="data row8 col2" >gpt-4o-mini</td>
#       <td id="T_ef32f_row8_col3" class="data row8 col3" >579</td>
#       <td id="T_ef32f_row8_col4" class="data row8 col4" >123</td>
#       <td id="T_ef32f_row8_col5" class="data row8 col5" >702</td>
#       <td id="T_ef32f_row8_col6" class="data row8 col6" >2.740000</td>
#       <td id="T_ef32f_row8_col7" class="data row8 col7" >0.000161</td>
#     </tr>
#     <tr>
#       <th id="T_ef32f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ef32f_row9_col0" class="data row9 col0" >TOTAL</td>
#       <td id="T_ef32f_row9_col1" class="data row9 col1" >—</td>
#       <td id="T_ef32f_row9_col2" class="data row9 col2" >—</td>
#       <td id="T_ef32f_row9_col3" class="data row9 col3" >4425</td>
#       <td id="T_ef32f_row9_col4" class="data row9 col4" >2309</td>
#       <td id="T_ef32f_row9_col5" class="data row9 col5" >6734</td>
#       <td id="T_ef32f_row9_col6" class="data row9 col6" >52.680000</td>
#       <td id="T_ef32f_row9_col7" class="data row9 col7" >0.002050</td>
#     </tr>
#   </tbody>
# </table>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#16a34a;background:#ecfdf5;
#                  margin:4px 0;">
#       UC3 Budget: $0.0021
#     </span>

# %% [markdown]
# ## UC4 — Procurement-Prompt Auditor
#
# ### **Procurement prompts to cut through hype**
# **Goal:** Turn six procurement questions into a structured **agentic maturity audit**.
#
# We:
# 1. Present the six prompts,
# 2. Have the system produce a short audit report for a named vendor,
# 3. Parse a strict JSON summary of **Q1–Q6** from the model output.
#
# You can change `vendor_name` and `context` to match your audience.
#
# 👉 **Run the cell below** after UC3.

# %%
PROCUREMENT_QUESTIONS = [
    "Q1: Show traces for a 10-step task with retries/branching.",
    "Q2: Run your ablation: turn off planning—how does success change?",
    "Q3: Lock a key tool—what’s the fallback behavior?",
    "Q4: What policy prevents data exfiltration via copy/paste or uploads?",
    "Q5: What’s your budget governor (time/steps/$) and enforcement?",
    "Q6: How do you detect/mitigate prompt injection?",
]


def extract_json_block(text: str) -> Optional[Dict[str, Any]]:
    import re as _re

    m = _re.search(r"```\s*json\s*\n(.*?)```", text, flags=_re.S | _re.I)
    if not m:
        return None
    raw = m.group(1)
    try:
        return json.loads(raw)
    except Exception:
        return None


def run_uc4():
    use_case = "UC4"

    vendor_name = "OpenAI Operator / Computer-Using Agent (example)"
    context = (
        "We want to assess how mature this vendor is in deploying agentic systems with: "
        "traces, ablations, tool lock behavior, exfiltration safeguards, budget governance, and prompt-injection mitigations."
    )

    q_block = "\n".join(f"- {q}" for q in PROCUREMENT_QUESTIONS)

    outline = researcher_agent(
        f"Vendor: {vendor_name}\n\nContext:\n{context}\n\nProcurement prompts:\n{q_block}\n\n"
        "Outline an audit structure with a section per question (Q1..Q6).",
        use_case,
    )

    writer_prompt = (
        f"Write a concise procurement audit report for vendor: {vendor_name}.\n"
        "Use the outline below, and for each Q1..Q6 provide:\n"
        "- Status: pass | partial | missing (lowercase)\n"
        "- 1–3 bullets of evidence (even if speculative, mark assumptions)\n\n"
        "END the report with a fenced JSON block using EXACTLY this shape:\n"
        "```json\n"
        "{\n"
        '  "questions": [\n'
        '    {"id":"Q1","status":"pass|partial|missing","evidence":"short note"},\n'
        '    {"id":"Q2","status":"pass|partial|missing","evidence":"short note"},\n'
        '    {"id":"Q3","status":"pass|partial|missing","evidence":"short note"},\n'
        '    {"id":"Q4","status":"pass|partial|missing","evidence":"short note"},\n'
        '    {"id":"Q5","status":"pass|partial|missing","evidence":"short note"},\n'
        '    {"id":"Q6","status":"pass|partial|missing","evidence":"short note"}\n'
        "  ],\n"
        '  "notes": "free-text notes"\n'
        "}\n"
        "```\n\n"
        "Outline:\n" + outline
    )

    report = writer_agent(writer_prompt, use_case)
    critique = critic_agent(
        report,
        use_case,
        focus="ambiguous or weak evidence and missing risks for each question",
    )

    final_text = report + "\n\n---\nCritic suggestions (apply separately):\n" + critique
    show_card("UC4 — Procurement Audit Report (Draft + Critique)", final_text, kind="info")

    audit_json = extract_json_block(final_text)
    if audit_json is None:
        fallback = judge_text(final_text, use_case, label="procurement_json_infer")
        audit_json = {"questions": [], "notes": fallback.get("notes", "No JSON extracted.")}

    rows = []
    for q in PROCUREMENT_QUESTIONS:
        qid = q.split(":")[0]
        rec = next(
            (x for x in audit_json.get("questions", []) if x.get("id") == qid),
            None,
        )
        status = (rec or {}).get("status", "missing").lower()
        evidence = (rec or {}).get("evidence", "")
        rows.append({"Question": q, "Status": status, "Evidence": evidence})
    df = pd.DataFrame(rows)
    show_table(df, "UC4 — Q1..Q6 Audit Summary")

    statuses = [r["Status"] for r in rows]
    if statuses and all(s == "pass" for s in statuses):
        show_badge("Procurement Audit: STRONG", kind="success")
    elif any(s == "missing" for s in statuses):
        show_badge("Procurement Audit: GAPS", kind="warn")
    else:
        show_badge("Procurement Audit: MIXED", kind="info")

    show_run_summary(use_case)


# Run UC4
run_uc4()
# Out:
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC4 · Researcher (analysis/outline) — 899 tok, 16.65s, $0.0004
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC4 · Writer (draft) — 1610 tok, 12.95s, $0.0005
#     </span>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC4 · Critic (review) — 1019 tok, 5.15s, $0.0003
#     </span>
#     <div style="border-radius:12px;padding:12px 14px;margin:10px 0;
#                 border:1px solid #0ea5e9;background:#f0f9ff;">
#       <div style="font-weight:700;color:#0ea5e9;margin-bottom:4px;">UC4 — Procurement Audit Report (Draft + Critique)</div>
#       <div style="white-space:pre-wrap;line-height:1.4;font-size:14px;"># Procurement Audit Report for OpenAI Operator / Computer-Using Agent
#
# ## 1. Traces for a 10-Step Task with Retries/Branching (Q1)
# - **Status**: partial
#   - Sample traces provided, but limited in detail regarding retries.
#   - Some clarity in successful task completions, but unsuccessful completions lack comprehensive analysis.
#   - Assumption: Vendor has the capability to generate more detailed traces if requested.
#
# ## 2. Ablation Study on Planning (Q2)
# - **Status**: missing
#   - No results provided from an ablation test assessing planning impact.
#   - Lack of comparative analysis between tasks executed with and without planning.
#   - Assumption: Vendor may not have conducted such tests yet.
#
# ## 3. Tool Lock Behavior (Q3)
# - **Status**: pass
#   - Documentation outlines fallback mechanisms when key tools are locked.
#   - Case studies demonstrate effective fallback behavior in real scenarios.
#   - User feedback indicates satisfaction with fallback responses.
#
# ## 4. Data Exfiltration Safeguards (Q4)
# - **Status**: partial
#   - Policies on data handling exist but lack detailed implementation examples.
#   - Some safeguards documented, such as copy/paste restrictions, but effectiveness assessments are missing.
#   - Assumption: Vendor is actively working on enhancing policy enforcement.
#
# ## 5. Budget Governance (Q5)
# - **Status**: missing
#   - No documentation provided regarding budget governance policies.
#   - Lack of examples demonstrating budget adherence or metrics on compliance.
#   - Assumption: Vendor may not have established formal budget governance mechanisms.
#
# ## 6. Detection and Mitigation of Prompt Injection (Q6)
# - **Status**: partial
#   - Some documentation on detection methods exists, but details on mitigation strategies are sparse.
#   - Limited case studies provided, with few metrics on prompt injection incidents.
#   - Assumption: Vendor has ongoing efforts to improve detection and mitigation.
#
# ### Conclusion
# - The audit reveals mixed results regarding the maturity of OpenAI's agentic systems.
# - Areas of strength include tool lock behavior and some aspects of data exfiltration safeguards.
# - Significant gaps exist in planning ablation studies, budget governance, and prompt injection strategies.
# - Recommendations include conducting comprehensive ablation studies, formalizing budget governance, and enhancing documentation on prompt injection responses.
#
# ```json
# {
#   "questions": [
#     {"id":"Q1","status":"partial","evidence":"Sample traces provided, but limited in detail regarding retries."},
#     {"id":"Q2","status":"missing","evidence":"No results provided from an ablation test assessing planning impact."},
#     {"id":"Q3","status":"pass","evidence":"Documentation outlines fallback mechanisms when key tools are locked."},
#     {"id":"Q4","status":"partial","evidence":"Policies on data handling exist but lack detailed implementation examples."},
#     {"id":"Q5","status":"missing","evidence":"No documentation provided regarding budget governance policies."},
#     {"id":"Q6","status":"partial","evidence":"Some documentation on detection methods exists, but details on mitigation strategies are sparse."}
#   ],
#   "notes": "Mixed results indicate areas for improvement, particularly in planning and budget governance."
# }
# ```
#
# ---
# Critic suggestions (apply separately):
# - **Q1 (Traces for a 10-Step Task with Retries/Branching)**:
#   - Clarify what specific details are missing regarding retries. Are there particular metrics or examples that would enhance understanding?
#   - Provide evidence or examples of unsuccessful completions to support the claim of lacking comprehensive analysis.
#
# - **Q2 (Ablation Study on Planning)**:
#   - Specify the importance of conducting an ablation study and the potential risks of not having this data. What could be the implications for task performance without this analysis?
#
# - **Q3 (Tool Lock Behavior)**:
#   - While the status is marked as pass, consider discussing potential risks associated with fallback mechanisms. What happens if fallback mechanisms fail or are insufficient?
#
# - **Q4 (Data Exfiltration Safeguards)**:
#   - Identify specific risks related to the lack of detailed implementation examples. How might this impact the effectiveness of the safeguards?
#   - Include a discussion on the potential consequences of ineffective data handling policies.
#
# - **Q5 (Budget Governance)**:
#   - Elaborate on the risks of not having budget governance policies in place. What could be the financial or operational impacts of this absence?
#
# - **Q6 (Detection and Mitigation of Prompt Injection)**:
#   - Highlight the risks associated with sparse mitigation strategies. What vulnerabilities does this create for the system?
#   - Suggest specific metrics or case studies that would strengthen the evidence provided for detection methods.</div>
#     </div>
# <div style='font-weight:600;margin:6px 0;'>UC4 — Q1..Q6 Audit Summary</div>
# <style type="text/css">
# #T_98aad th {
#   background-color: #e5e7eb;
# }
# </style>
# <table id="T_98aad" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98aad_level0_col0" class="col_heading level0 col0" >Question</th>
#       <th id="T_98aad_level0_col1" class="col_heading level0 col1" >Status</th>
#       <th id="T_98aad_level0_col2" class="col_heading level0 col2" >Evidence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98aad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98aad_row0_col0" class="data row0 col0" >Q1: Show traces for a 10-step task with retries/branching.</td>
#       <td id="T_98aad_row0_col1" class="data row0 col1" >partial</td>
#       <td id="T_98aad_row0_col2" class="data row0 col2" >Sample traces provided, but limited in detail regarding retries.</td>
#     </tr>
#     <tr>
#       <th id="T_98aad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98aad_row1_col0" class="data row1 col0" >Q2: Run your ablation: turn off planning—how does success change?</td>
#       <td id="T_98aad_row1_col1" class="data row1 col1" >missing</td>
#       <td id="T_98aad_row1_col2" class="data row1 col2" >No results provided from an ablation test assessing planning impact.</td>
#     </tr>
#     <tr>
#       <th id="T_98aad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98aad_row2_col0" class="data row2 col0" >Q3: Lock a key tool—what’s the fallback behavior?</td>
#       <td id="T_98aad_row2_col1" class="data row2 col1" >pass</td>
#       <td id="T_98aad_row2_col2" class="data row2 col2" >Documentation outlines fallback mechanisms when key tools are locked.</td>
#     </tr>
#     <tr>
#       <th id="T_98aad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98aad_row3_col0" class="data row3 col0" >Q4: What policy prevents data exfiltration via copy/paste or uploads?</td>
#       <td id="T_98aad_row3_col1" class="data row3 col1" >partial</td>
#       <td id="T_98aad_row3_col2" class="data row3 col2" >Policies on data handling exist but lack detailed implementation examples.</td>
#     </tr>
#     <tr>
#       <th id="T_98aad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98aad_row4_col0" class="data row4 col0" >Q5: What’s your budget governor (time/steps/$) and enforcement?</td>
#       <td id="T_98aad_row4_col1" class="data row4 col1" >missing</td>
#       <td id="T_98aad_row4_col2" class="data row4 col2" >No documentation provided regarding budget governance policies.</td>
#     </tr>
#     <tr>
#       <th id="T_98aad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_98aad_row5_col0" class="data row5 col0" >Q6: How do you detect/mitigate prompt injection?</td>
#       <td id="T_98aad_row5_col1" class="data row5 col1" >partial</td>
#       <td id="T_98aad_row5_col2" class="data row5 col2" >Some documentation on detection methods exists, but details on mitigation strategies are sparse.</td>
#     </tr>
#   </tbody>
# </table>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#f59e0b;background:#fffbeb;
#                  margin:4px 0;">
#       Procurement Audit: GAPS
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC4 — Cost/Latency Summary</div>
# <style type="text/css">
# #T_c9888 th {
#   background-color: #e5e7eb;
# }
# </style>
# <table id="T_c9888" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9888_level0_col0" class="col_heading level0 col0" >Agent</th>
#       <th id="T_c9888_level0_col1" class="col_heading level0 col1" >Role</th>
#       <th id="T_c9888_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_c9888_level0_col3" class="col_heading level0 col3" >Prompt tok</th>
#       <th id="T_c9888_level0_col4" class="col_heading level0 col4" >Completion tok</th>
#       <th id="T_c9888_level0_col5" class="col_heading level0 col5" >Total tok</th>
#       <th id="T_c9888_level0_col6" class="col_heading level0 col6" >Latency (s)</th>
#       <th id="T_c9888_level0_col7" class="col_heading level0 col7" >Cost (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9888_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9888_row0_col0" class="data row0 col0" >Researcher</td>
#       <td id="T_c9888_row0_col1" class="data row0 col1" >analysis/outline</td>
#       <td id="T_c9888_row0_col2" class="data row0 col2" >gpt-4o-mini</td>
#       <td id="T_c9888_row0_col3" class="data row0 col3" >227</td>
#       <td id="T_c9888_row0_col4" class="data row0 col4" >672</td>
#       <td id="T_c9888_row0_col5" class="data row0 col5" >899</td>
#       <td id="T_c9888_row0_col6" class="data row0 col6" >16.650000</td>
#       <td id="T_c9888_row0_col7" class="data row0 col7" >0.000437</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9888_row1_col0" class="data row1 col0" >Writer</td>
#       <td id="T_c9888_row1_col1" class="data row1 col1" >draft</td>
#       <td id="T_c9888_row1_col2" class="data row1 col2" >gpt-4o-mini</td>
#       <td id="T_c9888_row1_col3" class="data row1 col3" >946</td>
#       <td id="T_c9888_row1_col4" class="data row1 col4" >664</td>
#       <td id="T_c9888_row1_col5" class="data row1 col5" >1610</td>
#       <td id="T_c9888_row1_col6" class="data row1 col6" >12.950000</td>
#       <td id="T_c9888_row1_col7" class="data row1 col7" >0.000540</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c9888_row2_col0" class="data row2 col0" >Critic</td>
#       <td id="T_c9888_row2_col1" class="data row2 col1" >review</td>
#       <td id="T_c9888_row2_col2" class="data row2 col2" >gpt-4o-mini</td>
#       <td id="T_c9888_row2_col3" class="data row2 col3" >729</td>
#       <td id="T_c9888_row2_col4" class="data row2 col4" >290</td>
#       <td id="T_c9888_row2_col5" class="data row2 col5" >1019</td>
#       <td id="T_c9888_row2_col6" class="data row2 col6" >5.150000</td>
#       <td id="T_c9888_row2_col7" class="data row2 col7" >0.000283</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c9888_row3_col0" class="data row3 col0" >TOTAL</td>
#       <td id="T_c9888_row3_col1" class="data row3 col1" >—</td>
#       <td id="T_c9888_row3_col2" class="data row3 col2" >—</td>
#       <td id="T_c9888_row3_col3" class="data row3 col3" >1902</td>
#       <td id="T_c9888_row3_col4" class="data row3 col4" >1626</td>
#       <td id="T_c9888_row3_col5" class="data row3 col5" >3528</td>
#       <td id="T_c9888_row3_col6" class="data row3 col6" >34.750000</td>
#       <td id="T_c9888_row3_col7" class="data row3 col7" >0.001260</td>
#     </tr>
#   </tbody>
# </table>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#16a34a;background:#ecfdf5;
#                  margin:4px 0;">
#       UC4 Budget: $0.0013
#     </span>

# %% [markdown]
# ## UC5 — Frontier Signals Monitor (Heuristic / Speculative)
#
# ### **Monitoring and Operational Postures**
# **Goal:** Illustrate how we might **organize** frontier signals:
#
# - `reasoning_depth`
# - `goal_fidelity`
# - `cross_domain_transfer`
# - `autonomy_score`
#
# ⚠️ **Important:** These metrics are **heuristic, model-generated, and speculative** — NOT measured system telemetry.
#
# We use GPT-4o-mini to structure the metrics and notes, but they must be grounded in separate empirical evaluation.
#
# 👉 **Run the cell below** after UC4.

# %%
def run_uc5():
    use_case = "UC5"
    sys = (
        "You are helping design a frontier signals dashboard for agentic AI. "
        "Given the description below, propose 4 normalized metrics in [0,1]:"
        "- reasoning_depth"
        "- goal_fidelity"
        "- cross_domain_transfer"
        "- autonomy_score"
        "Return STRICT JSON ONLY with keys:\n"
          "  reasoning_depth (0-1), goal_fidelity(0-1), cross_domain_transfer(0-1), fautonomy_score, notes (string).\n"
        "No extra commentary."
    )
    desc = (
        "We have a suite of agentic systems deployed in production (code assist, knowledge ops, and limited computer-use agents). "
        "We want a pragmatic 'watchlist' to know when behavior is drifting toward higher autonomy, longer-horizon competence, "
        "and stronger cross-domain generalization, so that we can tighten governance and increase eval cadence."
    )
    messages = [
        {"role": "system", "content": sys},
        {"role": "user", "content": desc},
    ]
    raw, meta = call_llm(messages, model=MODEL_ID, temperature=0.1, max_tokens=400)
    log_agent_run(use_case, "FrontierMonitor", "metrics", meta)
    try:
        obj = json.loads(raw)
    except Exception:
        obj = {
            "reasoning_depth": 0.0,
            "goal_fidelity": 0.0,
            "cross_domain_transfer": 0.0,
            "autonomy_score": 0.0,
            "notes": f"Parse error; model output was: {raw[:120]}...",
        }
    show_json(obj, "UC5 — Frontier Signals (Heuristic)")
    show_badge("⚠️ Frontier metrics are heuristic / speculative — not empirical.", kind="warn")
    show_run_summary(use_case)


# Run UC5
run_uc5()
# Out:
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#0ea5e9;background:#f0f9ff;
#                  margin:4px 0;">
#       UC5 · FrontierMonitor (metrics) — 239 tok, 1.50s, $0.0001
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC5 — Frontier Signals (Heuristic)</div>
# <pre style='background:#020617;color:#e5e7eb;padding:10px;border-radius:8px;font-size:12px;'>{   "reasoning_depth": 0.75,   "goal_fidelity": 0.85,   "cross_domain_transfer": 0.65,   "autonomy_score": 0.7,   "notes": "Metrics indicate a strong
#
#  performance in reasoning and goal alignment, with moderate cross-domain capabilities and autonomy, suggesting a need for increased oversight." }</pre>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#f59e0b;background:#fffbeb;
#                  margin:4px 0;">
#       ⚠️ Frontier metrics are heuristic / speculative — not empirical.
#     </span>
# <div style='font-weight:600;margin:6px 0;'>UC5 — Cost/Latency Summary</div>
# <style type="text/css">
# #T_41ddf th {
#   background-color: #e5e7eb;
# }
# </style>
# <table id="T_41ddf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41ddf_level0_col0" class="col_heading level0 col0" >Agent</th>
#       <th id="T_41ddf_level0_col1" class="col_heading level0 col1" >Role</th>
#       <th id="T_41ddf_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_41ddf_level0_col3" class="col_heading level0 col3" >Prompt tok</th>
#       <th id="T_41ddf_level0_col4" class="col_heading level0 col4" >Completion tok</th>
#       <th id="T_41ddf_level0_col5" class="col_heading level0 col5" >Total tok</th>
#       <th id="T_41ddf_level0_col6" class="col_heading level0 col6" >Latency (s)</th>
#       <th id="T_41ddf_level0_col7" class="col_heading level0 col7" >Cost (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41ddf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41ddf_row0_col0" class="data row0 col0" >FrontierMonitor</td>
#       <td id="T_41ddf_row0_col1" class="data row0 col1" >metrics</td>
#       <td id="T_41ddf_row0_col2" class="data row0 col2" >gpt-4o-mini</td>
#       <td id="T_41ddf_row0_col3" class="data row0 col3" >162</td>
#       <td id="T_41ddf_row0_col4" class="data row0 col4" >77</td>
#       <td id="T_41ddf_row0_col5" class="data row0 col5" >239</td>
#       <td id="T_41ddf_row0_col6" class="data row0 col6" >1.500000</td>
#       <td id="T_41ddf_row0_col7" class="data row0 col7" >0.000070</td>
#     </tr>
#     <tr>
#       <th id="T_41ddf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41ddf_row1_col0" class="data row1 col0" >TOTAL</td>
#       <td id="T_41ddf_row1_col1" class="data row1 col1" >—</td>
#       <td id="T_41ddf_row1_col2" class="data row1 col2" >—</td>
#       <td id="T_41ddf_row1_col3" class="data row1 col3" >162</td>
#       <td id="T_41ddf_row1_col4" class="data row1 col4" >77</td>
#       <td id="T_41ddf_row1_col5" class="data row1 col5" >239</td>
#       <td id="T_41ddf_row1_col6" class="data row1 col6" >1.500000</td>
#       <td id="T_41ddf_row1_col7" class="data row1 col7" >0.000070</td>
#     </tr>
#   </tbody>
# </table>
#     <span style="display:inline-block;padding:4px 10px;border-radius:999px;
#                  font-size:12px;font-weight:600;color:#16a34a;background:#ecfdf5;
#                  margin:4px 0;">
#       UC5 Budget: $0.0001
#     </span>

# %% [markdown]
# ## Wrap-Up
#
# This notebook provide five live, multi-agent demonstrations using GPT-4o-mini to show how to build and audit production-ready-agentic systems
#
# - **UC1** — Hybrid orchestration as *plan → act → reflect*
# - **UC2** — LOA-A and modes as *risk × reversibility* decisions
# - **UC3** — Truth tests and meta-scans for agentic reasoning
# - **UC4** — Procurement prompts turned into structured audits
# - **UC5** — Frontier metrics organized as a pragmatic watchlist
