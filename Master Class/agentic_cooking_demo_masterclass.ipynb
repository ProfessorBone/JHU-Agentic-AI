# %% [markdown]
# # Agentic Cooking Intelligence — Dual-Mode (Offline/Online) — **Course Edition**
#
# This notebook includes the same topics that were presented in the scene parsing master class; because of the complexity of the demo code, I built you this demo notebook so that you could more easily explore the underlying agentic concepts.  Thanks so much for being part of our program.  (Will)

# %% [markdown]
# ## 1) Mode & Proxy Setup

# %%
# === Runtime Mode ===
MODE = "ONLINE"  # change to "OFFLINE" for no-network runs

# Provide your GL key via env/secret or paste here (for ONLINE)
from google.colab import userdata

try:
    GL_OpenAI = userdata.get('GL_OpenAI') # noqa
except NameError:
    GL_OpenAI = None  # e.g., "gl-..."

API_BASE = "https://aibe.mygreatlearning.com/openai/v1"
MODEL_ID = "gpt-4o-mini"
EMBED_MODEL = "text-embedding-3-small"

def is_online():
    return MODE.upper() == "ONLINE" and GL_OpenAI not in (None, "", "REPLACE_ME")

print("MODE:", MODE, "| GL key configured:", bool(GL_OpenAI and GL_OpenAI != "REPLACE_ME"), "| Online:", is_online())
# Out:
# MODE: ONLINE | GL key configured: True | Online: True

# %% [markdown]
# ## 2) 📦 UI Helpers (Pretty Output)

# %%
from IPython.display import display, HTML
import json as _json, html as _html
import pandas as pd
import textwrap

def show_card(title, subtitle=None, body_html=""):
    subtitle = subtitle or ""
    styles = (
        "<style>"
        ".nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;"
        "box-shadow:0 1px 2px rgba(0,0,0,0.04);}"
        ".nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}"
        ".nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}"
        ".nb-body{font-size:14px;line-height:1.45}"
        ".nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;"
        "font-size:12px;margin-left:6px;}"
        "</style>"
    )
    html = (
        styles +
        '<div class="nb-card">'
        f'<div class="nb-title">{title}</div>'
        f'<div class="nb-sub">{subtitle}</div>'
        f'<div class="nb-body">{body_html}</div>'
        "</div>"
    )
    display(HTML(html))

def show_json(obj, title="JSON"):
    formatted = _json.dumps(obj, indent=2, ensure_ascii=False)
    body = '<pre style="white-space:pre-wrap">' + _html.escape(formatted) + '</pre>'
    show_card(title, body_html=body)

def show_table(rows, columns=None, title="Table", subtitle=None, index=False):
    df = pd.DataFrame(rows, columns=columns) if columns else pd.DataFrame(rows)
    show_card(title, subtitle=subtitle, body_html=df.to_html(index=index))

def show_hits(hits, title="Retrieved Context"):
    rows = [{"#": i+1, "key": k, "score": round(s, 3)} for i,(k,_,s) in enumerate(hits)]
    show_table(rows, title=title, subtitle=f"{len(rows)} items", index=False)

def show_coverage(cov, title="Coverage"):
    found = ", ".join(cov.get("found", [])) or "—"
    missing = ", ".join(cov.get("missing", [])) or "—"
    pct = f"{int(100*cov.get('coverage',0))}%"
    body = "<b>Coverage:</b> " + pct + "<br/><b>Found:</b> " + found + "<br/><b>Missing:</b> " + missing
    show_card(title, body_html=body)

def show_badge(label, ok, note=""):
    color = "#10b981" if ok else "#f59e0b"
    text = "PASS" if ok else "SKIP/FAIL"
    html = (
        '<div class="nb-card">'
        f'<div class="nb-title">{label}<span class="nb-badge" style="border-color:{color};color:{color};">{text}</span></div>'
        f'<div class="nb-body">{textwrap.fill(note, 120)}</div>'
        "</div>"
    )
    display(HTML(html))

# %% [markdown]
# ## 3) Clients — GL Chat/Embeddings (online) + FakeLM (offline)

# %%
import json, requests, numpy as np

class GLChatClient:
    def __init__(self, api_key, api_base=API_BASE, model=MODEL_ID):
        self.api_key = api_key; self.api_base = api_base.rstrip("/"); self.model=model
    def generate(self, messages, **kwargs):
        url = f"{self.api_base}/chat/completions"
        headers = {"Authorization": f"Bearer {self.api_key}", "Content-Type": "application/json"}
        payload = {"model": self.model, "messages": messages}
        payload.update(kwargs or {})
        r = requests.post(url, headers=headers, json=payload, timeout=60)
        r.raise_for_status(); data = r.json()
        return data["choices"][0]["message"]["content"]

class GLEmbedClient:
    def __init__(self, api_key, api_base=API_BASE, model=EMBED_MODEL):
        self.api_key = api_key; self.api_base = api_base.rstrip("/"); self.model=model
    def embed(self, texts):
        if isinstance(texts, str): texts=[texts]
        url = f"{self.api_base}/embeddings"
        headers = {"Authorization": f"Bearer {self.api_key}", "Content-Type": "application/json"}
        payload = {"model": self.model, "input": texts}
        r = requests.post(url, headers=headers, json=payload, timeout=60)
        r.raise_for_status(); data = r.json()
        vecs = [np.array(d["embedding"], dtype=np.float32) for d in data["data"]]
        return np.vstack(vecs)

class FakeLM:
    def generate(self, messages, **kwargs):
        last = ""
        for m in messages[::-1]:
            c = m.get("content")
            if isinstance(c, str): last = c; break
        tips = []
        l = last.lower()
        if "emulsif" in l: tips += ["Reserve starchy water and fat to emulsify.", "Finish pasta in pan with vigorous tossing."]
        if "gluten" in l:  tips += ["Use rice/corn GF pasta; avoid cross-contamination."]
        if "safety" in l or "allergen" in l: tips += ["Mind the 5–60°C danger zone.", "Ask for allergies; swap ingredients safely."]
        if not tips: tips = ["Mise en place.", "Taste & adjust.", "Control heat and time."]
        return "\n".join("- " + t for t in tips[:6])

chat_client = GLChatClient(GL_OpenAI) if is_online() else FakeLM()

def chat(system, user, **kwargs):
    messages = []
    if system: messages.append({"role":"system","content":system})
    messages.append({"role":"user","content":user})
    try:
        return chat_client.generate(messages, **kwargs)
    except Exception as e:
        return "[chat error] " + str(e)

# %% [markdown]
# ## 4) Tiny In-Notebook Corpora

# %%
from collections import Counter
import math

task_corpus = {
    "pasta_basics.md": "Boil 1–2% salted water (~1L/100g). Reserve starchy water for emulsifying sauces.",
    "tomato_sauce.md": "Sauté garlic in oil, add tomatoes, simmer to thicken. Emulsify with pasta water; finish with basil.",
    "knife_safety.md": "Sharp knife, claw grip, stable board. Keep fingers tucked; cut away from yourself.",
}
policy_corpus = {
    "allergens.md": "Common allergens: gluten, dairy, nuts, eggs. Ask for allergies; suggest alternatives.",
    "food_safety.md": "Danger zone 5–60°C. Reheat leftovers to 74°C; refrigerate within 2 hours.",
    "substitutions.md": "If missing basil, try parsley/oregano. Gluten-free pasta alternatives: corn/rice-based.",
}
cuisine_corpora = {
    "eurocentric": [
        ("italian_pasta", "Pasta al pomodoro with olive oil, garlic, basil, tomatoes; emulsify with starchy water."),
        ("french_omelette", "Butter, eggs, fine herbs; avoid browning for tenderness."),
        ("greek_salad", "Tomatoes, cucumbers, olives, feta, olive oil, oregano; typically no lettuce."),
    ],
    "global": [
        ("italian_pasta", "Pasta al pomodoro..."),
        ("mexican_tacos", "Al pastor uses achiote, pineapple, pork on a trompo; serve on corn tortillas."),
        ("indian_dal", "Dal tadka with tempered cumin, mustard seed, garlic, chili."),
        ("japanese_miso", "Miso soup with dashi; add tofu, wakame, scallions off heat."),
        ("thai_green_curry", "Green curry paste + coconut milk; Thai basil, kaffir lime, fish sauce, palm sugar."),
    ],
    "mexican": [
        ("tacos_al_pastor", "Achiote-marinated pork with pineapple on a trompo; thin slices on corn tortillas."),
        ("salsa_verde", "Tomatillos, jalapeño, onion, cilantro, lime; char or boil tomatillos before blending."),
        ("frijoles", "Pinto beans simmered with onion/epazote; mash with cooking liquid for refritos."),
    ],
    "indian": [
        ("dal_tadka", "Toor/moong dal; temper cumin, mustard, garlic, chilies in ghee; finish with cilantro."),
        ("chana_masala", "Chickpeas with onion, tomato, ginger-garlic, chole masala, amchur."),
        ("jeera_rice", "Basmati with cumin tempered in ghee; rinse well for separate grains."),
    ],
    "japanese": [
        ("miso_soup", "Dashi with miso; add tofu, wakame, scallions off heat to avoid boiling miso."),
        ("tamago_yaki", "Rolled omelette with dashi/sugar; cook in layers in rectangular pan."),
        ("onigiri", "Salted rice balls; fillings like umeboshi or salmon; wrap with nori."),
    ],
    "italian": [
        ("pomodoro", "Tomatoes, garlic, olive oil, basil; finish pasta in pan with starchy water."),
        ("cacio_e_pepe", "Pecorino + black pepper; create a creamy emulsion with starchy water."),
        ("pesto_genovese", "Basil, pine nuts, garlic, olive oil, Parmigiano; keep cool to reduce oxidation."),
    ],
}
cuisine_keywords = {
    "mexican": {"corn","tortillas","achiote","tomatillo","cilantro","jalapeño","epazote","lime","beans"},
    "indian": {"dal","cumin","mustard","ghee","garam","chana","turmeric","masala","basmati","tadka"},
    "japanese": {"dashi","miso","tofu","wakame","scallions","nori","umeboshi","tamago","katsuobushi"},
    "italian": {"olive","basil","tomatoes","pecorino","parmigiano","garlic","pasta","emulsion","starchy"},
}

# %% [markdown]
# ## 5) Retrieval Helpers (BM25-lite)

# %%
def _bm25lite_score(query, doc):
    q_terms = query.lower().split(); d_terms = doc.lower().split()
    df = Counter(d_terms); score = 0.0
    for t in q_terms:
        tf = df.get(t, 0); score += tf / (tf + 0.5)
    score += len(set(q_terms) & set(d_terms)) * 0.1
    return score

def retrieve_task(query, k=3):
    scored = sorted((( _bm25lite_score(query, v), k, v) for k,v in task_corpus.items()), reverse=True)[:k]
    return [(name, text, score) for (score, name, text) in scored]

# %% [markdown]
# ## 6) Cuisine Vector Store — GL Embeddings **or** TF-IDF (auto)

# %%
def cosine_sim(a, b):
    a = a / (np.linalg.norm(a, axis=-1, keepdims=True) + 1e-9)
    b = b / (np.linalg.norm(b, axis=-1, keepdims=True) + 1e-9)
    return a @ b.T

def build_cuisine_index(docs):
    if is_online():
        try:
            embedder = GLEmbedClient(GL_OpenAI)
            texts = [t for _, t in docs]
            mat = embedder.embed(texts)
            keys = [k for k,_ in docs]
            return ("embed", {"mat": mat, "keys": keys, "docs": docs})
        except Exception as e:
            print("[Embedding path error -> TF-IDF fallback]", e)
    # TF-IDF fallback
    vocab, df, tokenized = {}, Counter(), []
    for k,v in docs:
        toks=v.lower().split(); tokenized.append((k,toks))
        for t in set(toks): df[t]+=1; vocab.setdefault(t,len(vocab))
    N=len(docs); import math
    idf={t: math.log((1+N)/(1+df[t]))+1 for t in df}
    mat, keys = [], []
    for k,toks in tokenized:
        tf=Counter(toks); import numpy as np
        vec=np.zeros(len(vocab), dtype=np.float32)
        for t,c in tf.items():
            j=vocab.get(t)
            if j is not None: vec[j]=(c/len(toks))*idf.get(t,1.0)
        nrm=np.linalg.norm(vec) or 1.0
        mat.append(vec/nrm); keys.append(k)
    import numpy as np
    return ("tfidf", {"vocab":vocab,"idf":idf,"mat":np.vstack(mat),"keys":keys,"docs":docs})

def search_cuisine(index, query, top_k=3):
    mode, state = index[0], index[1]
    # Primary: embedding path if available
    if mode == "embed" and is_online():
        try:
            qvec = GLEmbedClient(GL_OpenAI).embed([query])
            sims = cosine_sim(qvec, state["mat"]).ravel()
            order = np.argsort(-sims)[:top_k]
            return [(state["docs"][i][0], state["docs"][i][1], float(sims[i])) for i in order]
        except Exception as e:
            print("[Search embedding error -> TF-IDF fallback]", e)
    # Robust fallback: build a temporary TF-IDF index from docs in state if needed
    docs = state.get("docs") if isinstance(state, dict) else None
    if docs is None:
        # If the structure is already TF-IDF, proceed; otherwise try to recover docs list
        docs = state.get("docs", [])
    # If we already have TF-IDF keys, use them directly
    if all(k in state for k in ("vocab","idf","mat","keys","docs")):
        st = state
    else:
        # Build a minimal TF-IDF index on the fly
        from collections import Counter as _Counter
        import numpy as _np, math as _math
        vocab, df, tokenized = {}, _Counter(), []
        for k,v in docs:
            toks=v.lower().split(); tokenized.append((k,toks))
            for t in set(toks): df[t]+=1; vocab.setdefault(t,len(vocab))
        N=len(docs) or 1
        idf={t: _math.log((1+N)/(1+df[t]))+1 for t in df}
        mat, keys = [], []
        for k,toks in tokenized:
            tf=_Counter(toks); vec=_np.zeros(len(vocab), dtype=_np.float32)
            for t,c in tf.items():
                j=vocab.get(t)
                if j is not None: vec[j]=(c/len(toks))*idf.get(t,1.0)
            nrm=_np.linalg.norm(vec) or 1.0
            mat.append(vec/nrm); keys.append(k)
        st = {"vocab":vocab,"idf":idf,"mat":_np.vstack(mat) if len(mat)>0 else _np.zeros((0,0), dtype=_np.float32),
              "keys":keys,"docs":docs}
    # TF-IDF scoring
    vocab,idf,mat,keys,docs = st["vocab"],st["idf"],st["mat"],st["keys"],st["docs"]
    import numpy as _np
    toks=query.lower().split()
    q=_np.zeros(mat.shape[1] if mat.size else len(vocab) or 1, dtype=_np.float32)
    from collections import Counter as _Counter2
    tf=_Counter2(toks)
    for t,c in tf.items():
        j=vocab.get(t)
        if j is not None:
            q[j]=(c/max(1,len(toks)))*idf.get(t,1.0)
    denom = _np.linalg.norm(q)
    if denom: q = q/denom
    sims = (mat @ q) if mat.size else _np.zeros((len(docs),), dtype=_np.float32)
    order = _np.argsort(-sims)[:min(top_k, len(docs))]
    return [(docs[i][0], docs[i][1], float(sims[i])) for i in order]

# %% [markdown]
# ## Demo: Task Helper

# %%
def rag_task(query, k=3):
    hits = retrieve_task(query, k=k)
    context = "\n\n".join(["### " + n + "\n" + t for n,t,_ in hits])
    ans = chat("Answer only from the provided context.", "Context:\n" + context + "\n\nQ: " + query + "\nAnswer concisely.")
    return ans, hits

ans, hits = rag_task("How do I make tomato sauce cling to pasta?")
show_hits(hits, title="RAG — Retrieved")
show_card("RAG — Answer", body_html="<pre style='white-space:pre-wrap'>" + str(ans) + "</pre>")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">RAG — Retrieved</div><div class="nb-sub">3 items</div><div class="nb-body"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>key</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>tomato_sauce.md</td>
#       <td>0.767</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>pasta_basics.md</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>knife_safety.md</td>
#       <td>0.000</td>
#     </tr>
#   </tbody>
# </table></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">RAG — Answer</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>To make tomato sauce cling to pasta, emulsify the sauce with reserved starchy pasta water.</pre></div></div>

# %% [markdown]
# ## 8) Demo: Safety & Guidance

# %%
def rag_policy(query, k=2):
    task_hits = retrieve_task(query, k=k)
    task_ctx = "\n\n".join(["### " + n + "\n" + t for n,t,_ in task_hits])
    policy_ctx = "\n\n".join(["### " + n + "\n" + t for n,t in policy_corpus.items()])
    context = task_ctx + "\n\n" + policy_ctx
    ans = chat("Use the context; include safety/allergen guidance as relevant.", "Context:\n" + context + "\n\nQ: " + query + "\nProvide steps + safety notes + substitutions.")
    return ans, task_hits

ans_b, hits_b = rag_policy("Make a quick tomato pasta for someone who might be gluten-sensitive.")
show_card("RAG — Answer", body_html="<pre style='white-space:pre-wrap'>" + str(ans_b) + "</pre>")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">RAG — Answer</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>### Quick Tomato Pasta for Gluten-Sensitive Individuals
#
# #### Ingredients:
# - Gluten-free pasta (corn or rice-based)
# - Olive oil
# - Garlic (2-3 cloves, minced)
# - Canned or fresh tomatoes (400g)
# - Fresh basil (or substitute with parsley/oregano)
# - Salt
# - Pepper
#
# #### Steps:
# 1. **Boil Water**: Fill a pot with 1 liter of water for every 100 grams of gluten-free pasta. Add salt (1–2% concentration) and bring to a boil.
#
# 2. **Cook Pasta**: Add the gluten-free pasta to boiling water and cook according to package instructions. Reserve about 1/2 cup of the starchy pasta water before draining.
#
# 3. **Make Sauce**: While the pasta is cooking, heat 2 tablespoons of olive oil in a pan over medium heat. Add minced garlic and sauté until fragrant (about 1 minute), being careful not to burn it.
#
# 4. **Add Tomatoes**: Incorporate the canned or fresh tomatoes into the pan with the sautéed garlic. Let it simmer for about 10-15 minutes until the sauce thickens.
#
# 5. **Emulsify**: Add the reserved starchy pasta water to the tomato mixture to create a smoother sauce. Stir well to combine.
#
# 6. **Combine and Finish**: Add the drained gluten-free pasta to the sauce. Toss to coat evenly. Season with salt and pepper to taste, and stir in chopped fresh basil or your chosen herb substitute.
#
# 7. **Serve**: Plate the pasta and garnish with additional herbs if desired.
#
# #### Safety Notes:
# - **Allergy Considerations**: Always check ingredients for potential allergens; gluten sensitivity means avoiding standard wheat pasta.
# - **Food Safety**: If you have any leftovers, refrigerate them within 2 hours. When reheating, ensure to bring the temperature to at least 74°C to eliminate any harmful bacteria.
# - **Storage**: Keep in mind that cooked gluten-free pasta can become mushy if left too long; consume leftovers promptly.
#
# #### Substitutions:
# - **Herbs**: If basil is not available, consider using parsley or oregano as a flavorful substitute.
# - **Pasta Options**: If corn or rice pasta isn’t available, check for other gluten-free pasta alternatives that suit preference.
#
# Enjoy your gluten-sensitive tomato pasta!</pre></div></div>

# %% [markdown]
# ## 9) Demo: Cuisine Vector RAG + Coverage Check

# %%
def cuisine_coverage(answer, cuisine):
    keys = cuisine_keywords.get(cuisine.lower(), set())
    found = {k for k in keys if k in answer.lower()}
    return {"coverage": len(found)/max(1,len(keys)), "found": sorted(list(found)), "missing": sorted(list(keys - found))}

def rag_cuisine(corpus, query, cuisine_hint=None, top_k=3):
    docs = cuisine_corpora.get(corpus, [])
    idx = build_cuisine_index(docs)
    hits = search_cuisine(idx, query, top_k=top_k)
    context = "\n\n".join(["### " + k + "\n" + v for k,v,_ in hits])
    guard = "If context is culturally mismatched or insufficient, clearly note the gap and request clarification."
    ans = chat("You answer using only context. " + guard, "Context:\n" + context + "\n\nQ: " + query + "\nConcise, culturally aware answer.")
    cov = cuisine_coverage(ans, cuisine_hint or corpus)
    return ans, hits, cov

corpus, q, hint = "global", "Make gluten-free tacos with a bright salsa", "mexican"
a, h, c = rag_cuisine(corpus, q, cuisine_hint=hint, top_k=3)
show_hits(h, title="RAG — Hits (" + corpus + ")")
show_card("RAG — Answer", subtitle="query: " + q + " | hint: " + hint, body_html="<pre style='white-space:pre-wrap'>" + str(a) + "</pre>")
show_coverage(c, title="RAG — Coverage")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">RAG — Hits (global)</div><div class="nb-sub">3 items</div><div class="nb-body"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>#</th>
#       <th>key</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>mexican_tacos</td>
#       <td>0.398</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>japanese_miso</td>
#       <td>0.320</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>indian_dal</td>
#       <td>0.294</td>
#     </tr>
#   </tbody>
# </table></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">RAG — Answer</div><div class="nb-sub">query: Make gluten-free tacos with a bright salsa | hint: mexican</div><div class="nb-body"><pre style='white-space:pre-wrap'>To make gluten-free tacos, use corn tortillas as the base. For the filling, you can prepare grilled chicken or roasted vegetables seasoned with cumin and lime. For a bright salsa, mix diced tomatoes, red onion, cilantro, jalapeño, lime juice, and a pinch of salt. Combine the elements and serve fresh!</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">RAG — Coverage</div><div class="nb-sub"></div><div class="nb-body"><b>Coverage:</b> 55%<br/><b>Found:</b> cilantro, corn, jalapeño, lime, tortillas<br/><b>Missing:</b> achiote, beans, epazote, tomatillo</div></div>

# %% [markdown]
# ## 10) Bias Surfacing and Mitigation

# %%
def rate_candidate(c):
    prompt = (
        "Rate suitability using **task-relevant skills only**. Avoid prestige signals.\n"
        "Name: " + c["name"] + "\n"
        "Bio: " + c["bio"] + "\n"
        "Task: " + c["task"] + "\n"
        "Return JSON: {\"name\": \"...\", \"score\": <0-100>, \"justification\": \"...\"}"
    )
    return chat("You are a fair evaluator.", prompt)

candidates = [
    {"name":"Alex Taylor","bio":"Community college culinary cert; 4 years line cook; led staff meal program; strong sanitation.","task":"Design a 30-minute tomato pasta dinner for 4."},
    {"name":"Blair Jordan","bio":"Top-ranked culinary institute; 4 years line cook; led staff meal program; strong sanitation.","task":"Design a 30-minute tomato pasta dinner for 4."},
]
r1 = rate_candidate(candidates[0])
r2 = rate_candidate(candidates[1])
audit = chat("You are a bias auditor.", "We have two JSON ratings. Identify prestige bias and propose corrected scores. Return JSON.\n\n" + r1 + "\n\n" + r2)
fair = chat("You are a fair evaluator.", "Re-rate using the audit guidance. Return two JSON ratings.\n\nAudit:\n" + audit + "\n\nOriginal:\n" + r1 + "\n\n" + r2)

show_card("Bias — Raw Ratings", body_html="<pre style='white-space:pre-wrap'>" + r1 + "\n\n" + r2 + "</pre>")
show_card("Bias — Audit", body_html="<pre style='white-space:pre-wrap'>" + audit + "</pre>")
show_card("Bias — Fair Ratings", body_html="<pre style='white-space:pre-wrap'>" + fair + "</pre>")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Bias — Raw Ratings</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>{
#   "name": "Alex Taylor",
#   "score": 85,
#   "justification": "Alex has a community college culinary certification and 4 years of experience as a line cook, which provides a solid foundation in cooking techniques and kitchen operations. Leading a staff meal program demonstrates ability to plan and execute meals for groups, ensuring knowledge of portioning and timing is likely strong. Additionally, the emphasis on sanitation indicates a commitment to food safety, which is crucial in any culinary task. However, the score is not 100 as there is limited information about specific knowledge or experience with pasta dishes and sauce preparation."
# }
#
# ```json
# {
#   "name": "Blair Jordan",
#   "score": 85,
#   "justification": "Blair has experience as a line cook for 4 years, which provides them with practical cooking skills. Their background in a top-ranked culinary institute suggests a solid foundation in culinary techniques. Leading a staff meal program indicates competence in meal planning and execution, ensuring that they can design a cohesive dinner. Strong sanitation skills are essential in any cooking environment, contributing to food safety, which is crucial when preparing meals. However, lack of specific experience in designing recipes or menus could slightly lower the score."
# }
# ```</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Bias — Audit</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>The JSON ratings for Alex Taylor and Blair Jordan exhibit prestige bias. Alex Taylor has a community college culinary certification, while Blair has a background from a top-ranked culinary institute, which gives the impression that Blair might be more qualified despite them having the same level of practical experience as line cooks (4 years). This suggests an unjustified bias based on the prestige of the institution rather than skills and experience directly related to cooking.
#
# To correct the scores fairly while recognizing their qualifications without letting the prestige of the institutions disproportionately influence the evaluation, we can propose adjusted scores that reflect their equal experience and skills, focusing on practical capabilities rather than education prestige.
#
# Here’s the adjusted JSON:
#
# ```json
# [
#   {
#     "name": "Alex Taylor",
#     "score": 90,
#     "justification": "Alex has a community college culinary certification and 4 years of experience as a line cook, providing a solid foundation in cooking techniques and kitchen operations. Leading a staff meal program demonstrates ability in meal planning and execution, ensuring strong knowledge of portioning and timing. A commitment to sanitation indicates prioritization of food safety, which is crucial in culinary tasks. The score has been increased to reflect strong practical experience and skills."
#   },
#   {
#     "name": "Blair Jordan",
#     "score": 90,
#     "justification": "Blair has 4 years of experience as a line cook, equipping them with practical cooking skills. Their education in a top-ranked culinary institute does suggest a solid foundation in culinary techniques; however, their skills in meal planning and execution through leading a staff meal program are equally matched with Alex's practical experience. As such, their score has been adjusted to reflect their comparable skills, emphasizing practical abilities over institutional prestige."
#   }
# ]
# ```</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Bias — Fair Ratings</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>Based on the audit guidance provided, it seems necessary to adjust the original JSON ratings for both Alex Taylor and Blair Jordan to align with the evaluation criteria and to minimize prestige bias, ensuring their practical skills and experience take precedence in the ratings.
#
# Here is the revised JSON output reflecting the adjustments:
#
# ```json
# [
#   {
#     "name": "Alex Taylor",
#     "score": 90,
#     "justification": "Alex has a community college culinary certification and 4 years of experience as a line cook, providing a solid foundation in cooking techniques and kitchen operations. Leading a staff meal program demonstrates their ability in meal planning and execution, ensuring strong knowledge of portioning and timing. A commitment to sanitation indicates prioritization of food safety, which is crucial in culinary tasks. This score reflects strong practical experience and skills."
#   },
#   {
#     "name": "Blair Jordan",
#     "score": 90,
#     "justification": "Blair has 4 years of experience as a line cook, equipping them with practical cooking skills. Their education in a top-ranked culinary institute suggests a solid foundation in culinary techniques; however, their skills in meal planning and execution through leading a staff meal program are equally matched with Alex's practical experience. Therefore, this score highlights their comparable skills, emphasizing practical abilities over institutional prestige."
#   }
# ]
# ```
#
# This updated assessment maintains fairness by equally recognizing the practical experience and capabilities of both candidates, moving away from institutional bias in evaluating their qualifications.</pre></div></div>

# %% [markdown]
# ## 11) Compact Agent Loop

# %%
def planner(goal): return chat("You are a planning agent.", "Plan to achieve: " + goal + ". Bullet points.")
def executor(plan): return chat("You are an execution agent.", "Turn into 6 numbered steps:\n" + plan)
def auditor(steps): return chat("You are a safety/bias auditor.", "Review for food safety/allergens/unfair assumptions. If issues, list fixes; else 'Looks good.'\n\n" + steps)
def reviser(steps, audit): return chat("You are a reviser.", "Revise to address audit:\nAudit:\n" + audit + "\n\nSteps:\n" + steps)

goal = "Cook a dairy-free tomato pasta for 3 kids in 25 minutes."
plan = planner(goal); steps = executor(plan); check = auditor(steps)
show_card("Agent Plan", body_html="<pre style='white-space:pre-wrap'>" + plan + "</pre>")
show_card("Agent Steps", body_html="<pre style='white-space:pre-wrap'>" + steps + "</pre>")
show_card("Agent Audit", body_html="<pre style='white-space:pre-wrap'>" + check + "</pre>")
if "Looks good" not in check:
    revised = reviser(steps, check); show_card("Agent Revised Steps", body_html="<pre style='white-space:pre-wrap'>" + revised + "</pre>")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Agent Plan</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>### Cooking Plan for Dairy-Free Tomato Pasta (for 3 kids in 25 minutes)
#
# #### Ingredients
# - **Pasta** (e.g., spaghetti or penne) - 9 oz (about 3 cups uncooked)
# - **Olive oil** - 2 tablespoons
# - **Garlic** - 3 cloves, minced
# - **Onion** - 1 medium, diced
# - **Canned diced tomatoes** - 1 can (14 oz)
# - **Tomato paste** - 2 tablespoons
# - **Vegetable broth or water** - 1/2 cup
# - **Fresh or dried basil** - 1 teaspoon (optional)
# - **Salt and pepper** - to taste
# - **Vegetables** (optional; e.g., bell peppers, zucchini) - diced, as desired
# - **Nutritional yeast** (optional, for a cheesy flavor) - 2 tablespoons
#
# #### Equipment
# - Large pot for boiling pasta
# - Skillet or saucepan for sauce
# - Colander for draining pasta
# - Wooden spoon or spatula
# - Measuring cups and spoons
#
# #### Steps
# 1. **Boil Pasta (5 minutes)**
#    - Fill a large pot with water, add a pinch of salt, and bring to a boil.
#    - Add pasta and cook according to package instructions (usually about 8-10 minutes).
#
# 2. **Prepare Sauce (15 minutes overlap)**
#    - While the pasta is cooking, heat olive oil in a skillet over medium heat.
#    - Sauté diced onion for 2-3 minutes until translucent.
#    - Add minced garlic; sauté for 1 minute until fragrant.
#
# 3. **Add Tomatoes (5 minutes)**
#    - Pour in canned diced tomatoes and tomato paste; stir well.
#    - Add vegetable broth or water to thin the sauce slightly.
#    - Season with salt, pepper, and basil (if using).
#    - If using additional veggies, add them at this stage and cook for 5-7 minutes until tender.
#
# 4. **Combine & Finish (3 minutes)**
#    - Once the pasta is done, reserve a bit of pasta water and then drain the pasta.
#    - Add drained pasta to the sauce in the skillet; toss to combine.
#    - If the sauce is too thick, add reserved pasta water a little at a time until it reaches desired consistency.
#
# 5. **Serve**
#    - Plate the pasta and, if desired, sprinkle with nutritional yeast for a cheesy flavor.
#    - Let it cool slightly and serve to kids.
#
# ### Tips
# - Keep an eye on the timer to ensure everything finishes within 25 minutes.
# - Involve kids in simple tasks, like stirring pasta or adding seasoning.
# - Substitute any favorite vegetables or spices to cater to kids’ preferences.</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Agent Steps</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>### Cooking Plan for Dairy-Free Tomato Pasta (for 3 kids in 25 minutes)
#
# 1. **Boil Pasta (5 minutes)**
#    - Fill a large pot with water, add a pinch of salt, and bring to a boil.
#    - Add 9 oz of pasta and cook according to package instructions (usually 8-10 minutes).
#
# 2. **Prepare Sauce (15 minutes overlap)**
#    - While the pasta cooks, heat 2 tablespoons of olive oil in a skillet over medium heat.
#    - Sauté 1 medium diced onion for 2-3 minutes until translucent.
#    - Add 3 minced garlic cloves and sauté for 1 minute until fragrant.
#
# 3. **Add Tomatoes (5 minutes)**
#    - Stir in 1 can (14 oz) of canned diced tomatoes and 2 tablespoons of tomato paste.
#    - Add 1/2 cup of vegetable broth or water to thin the sauce.
#    - Season with salt, pepper, and 1 teaspoon of basil (if using). Add any diced vegetables and cook for 5-7 minutes until tender.
#
# 4. **Combine & Finish (3 minutes)**
#    - When the pasta is done, reserve some pasta water and drain the pasta.
#    - Add the drained pasta to the sauce in the skillet and toss to combine.
#    - If the sauce is too thick, add reserved pasta water gradually until the desired consistency is reached.
#
# 5. **Serve**
#    - Plate the pasta and, if desired, sprinkle with 2 tablespoons of nutritional yeast for a cheesy flavor.
#    - Let it cool slightly before serving to the kids.
#
# 6. **Tips**
#    - Keep an eye on the timer to ensure everything finishes within 25 minutes.
#    - Involve kids in simple tasks like stirring pasta or adding seasoning.
#    - Substitute any favorite vegetables or spices to cater to kids’ preferences.</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Agent Audit</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>### Review of Cooking Plan for Dairy-Free Tomato Pasta
#
# #### Food Safety:
# - The recipe involves perishable ingredients that should be handled safely. Ensure ingredients like garlic and onion are fresh and haven't been stored improperly.
# - Cooking temperatures aren't mentioned for the sauce preparation. Sautéing should reach at least 165°F (74°C) to ensure safety in case of any bacteria presence.
#
# ### Allergens:
# - The recipe is labeled as dairy-free, which is suitable for those with dairy allergies.
# - Check for any other allergens, particularly in the vegetable broth (some brands may include allergens like celery or soy).
# - Ensure the pasta is labeled as gluten-free if required for those with gluten intolerance or celiac disease.
#
# #### Unfair Assumptions:
# - The recipe assumes that all children enjoy a similar taste profile—particularly the use of onions and garlic. Consider including alternative suggestions for those who may have aversions to those flavors.
# - The instruction to involve kids in cooking isn't age-specific, which might not be suitable for younger children without supervision or assistance. Clarify which tasks are safe for various ages.
#
# ### Suggested Fixes:
# 1. **Food Safety:**
#    - Add a note on ensuring the cooking temperature reaches safe levels when preparing the sauce.
#    - Include a reminder to wash hands before handling food, as well as to clean utensils and surfaces.
#
# 2. **Allergen Consideration:**
#    - Specify checking the labels of vegetable broth for potential allergens and suggest alternatives if needed.
#    - Offer a gluten-free pasta option or mention potential allergens in the ingredients used.
#
# 3. **Addressing Children's Preferences:**
#    - Include a brief note suggesting alternatives for ingredients for children who may not like certain flavors (e.g., “If kids don't enjoy garlic, consider omitting it or using garlic powder for a milder flavor.”).
#
# 4. **Age Appropriateness:**
#    - Specify tasks that younger children can safely assist with and suggest adult supervision for knife skills or the use of the stove.
#
# Overall, the cooking plan serves as a good base but should incorporate these suggestions to enhance food safety, allergen awareness, and accommodate picky eaters.</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Agent Revised Steps</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>### Revised Cooking Plan for Dairy-Free Tomato Pasta (for 3 kids in 25 minutes)
#
# #### Food Safety:
# - Handle all perishable ingredients, such as garlic and onion, safely. Ensure they are fresh and have been stored properly.
# - The sauce should be cooked at a minimum temperature of 165°F (74°C) to eliminate any potential bacteria. Use a food thermometer to check if necessary.
# - Remember to wash hands thoroughly before handling any food and to clean all utensils and surfaces used during preparation.
#
# #### Allergens:
# - This recipe is labeled dairy-free, making it suitable for individuals with dairy allergies.
# - Check labels on vegetable broth for potential allergens, such as celery or soy, and consider suggesting allergen-free alternatives.
# - If gluten intolerance or celiac disease is a concern, make sure to choose gluten-free pasta.
#
# ### Addressing Unfair Assumptions:
# - The recipe presumes that all children enjoy onions and garlic equally. To accommodate varying tastes, consider adding options such as “If kids don’t enjoy garlic, you can omit it or opt for garlic powder for a milder flavor.”
# - Clarify the age-appropriateness of cooking tasks. Specify tasks safe for younger children and recommend adult supervision for any activities involving knives or cooking equipment.
#
# ### Suggested Fixes:
# 1. **Food Safety**:
#    - Include a reminder to reach a safe cooking temperature for the sauce.
#    - Emphasize the importance of hand washing, as well as cleanliness of surfaces and utensils.
#
# 2. **Allergen Consideration**:
#    - Direct users to check vegetable broth labels for allergens and suggest substitutions if necessary.
#    - Highlight the option for gluten-free pasta and mention possible allergens in listed ingredients.
#
# 3. **Children's Preferences**:
#    - Add a note suggesting alternatives for ingredients to accommodate picky eaters (e.g., “If children are not fond of garlic, consider omitting it or using garlic powder for a milder flavor.”).
#
# 4. **Age Appropriateness**:
#    - Specify age-appropriate tasks and emphasize adult supervision for younger children, particularly for knife skills or handling the stove.
#
# Overall, this cooking plan provides a sound foundation but should incorporate these enhancements to improve food safety, allergen awareness, and accommodate various taste preferences.
#
# ### Cooking Steps
#
# 1. **Boil Pasta (5 minutes)**:
#    - Fill a large pot with water, add a pinch of salt, and bring to a boil.
#    - Add 9 oz of pasta and cook according to package instructions (usually 8-10 minutes).
#
# 2. **Prepare Sauce (15 minutes overlap)**:
#    - While the pasta cooks, heat 2 tablespoons of olive oil in a skillet over medium heat.
#    - Sauté 1 medium diced onion for 2-3 minutes until translucent.
#    - Add 3 minced garlic cloves and sauté for 1 minute until fragrant. Ensure the mixture reaches a safe cooking temperature of 165°F (74°C).
#
# 3. **Add Tomatoes (5 minutes)**:
#    - Stir in 1 can (14 oz) of canned diced tomatoes and 2 tablespoons of tomato paste.
#    - Add 1/2 cup of vegetable broth or water to thin the sauce.
#    - Season with salt, pepper, and 1 teaspoon of basil (if using). Add any diced vegetables and cook for 5-7 minutes until tender.
#
# 4. **Combine & Finish (3 minutes)**:
#    - When the pasta is done, reserve some pasta water and drain the pasta.
#    - Add the drained pasta to the sauce in the skillet and toss to combine.
#    - If the sauce is too thick, gradually add reserved pasta water until the desired consistency is reached.
#
# 5. **Serve**:
#    - Plate the pasta and, if desired, sprinkle with 2 tablespoons of nutritional yeast for a cheesy flavor.
#    - Allow it to cool slightly before serving to the kids.
#
# 6. **Tips**:
#    - Keep an eye on the timer to ensure everything finishes within 25 minutes.
#    - Encourage kids to participate in simple tasks like stirring the pasta or adding seasonings but explain which tasks require supervision.
#    - Feel free to substitute favorite vegetables or spices to cater to children’s preferences.</pre></div></div>

# %% [markdown]
# ## 12) Scene Parsing Template (JSON)

# %%
schema = (
    "Return JSON with:\n"
    "{\n"
    "  \"objects\": [{\"name\": str, \"count\": int|null, \"notes\": str}], \n"
    "  \"risks\": [str],\n"
    "  \"missing_tools\": [str]\n"
    "}"
)
if is_online():
    try:
        out = GLChatClient(GL_OpenAI).generate([
            {"role":"system","content":"Output valid JSON only."},
            {"role":"user","content": schema},
            {"role":"user","content": "Parse the kitchen scene and suggest missing tools for tomato pasta."}
        ])
        show_card("Scene Parse — JSON", body_html="<pre style='white-space:pre-wrap'>" + out + "</pre>")
    except Exception as e:
        show_badge("Scene parsing", False, str(e))
else:
    stub = '{"objects":[{"name":"pot","count":1,"notes":"large"}],"risks":["knife near edge"],"missing_tools":["ladle","colander"]}'
    show_card("Scene Parse — JSON (Offline Stub)", body_html="<pre style='white-space:pre-wrap'>" + stub + "</pre>")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Scene Parse — JSON</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>{
#   "objects": [
#     {"name": "Tomatoes", "count": null, "notes": "Fresh or canned, used as the base for the sauce."},
#     {"name": "Pasta", "count": null, "notes": "Any type of pasta can be used."},
#     {"name": "Garlic", "count": null, "notes": "Adds flavor to the sauce."},
#     {"name": "Onion", "count": null, "notes": "Enhances the sauce's base flavor."},
#     {"name": "Olive oil", "count": null, "notes": "For cooking the sauce."},
#     {"name": "Salt", "count": null, "notes": "For seasoning."},
#     {"name": "Pepper", "count": null, "notes": "For seasoning."},
#     {"name": "Basil", "count": null, "notes": "Fresh is preferred for garnishing."},
#     {"name": "Parmesan cheese", "count": null, "notes": "For serving on top of the pasta."}
#   ],
#   "risks": [
#     "Possible food allergies (e.g., gluten in pasta, lactose in cheese).",
#     "Risk of burns while cooking."
#   ],
#   "missing_tools": [
#     "Large pot for boiling pasta",
#     "Frying pan for sauce preparation",
#     "Colander for draining pasta",
#     "Knife for chopping ingredients",
#     "Cutting board",
#     "Measuring cups and spoons",
#     "Serving utensils"
#   ]
# }</pre></div></div>

# %% [markdown]
# ## 13) Lightweight Evaluation

# %%
def score_answer(answer, must_include=None, max_len=160):
    must_include = must_include or []
    score, notes = 0, []
    if len(answer) <= max_len: score += 1
    for k in must_include:
        if k.lower() in answer.lower(): score += 1
        else: notes.append("Missing: " + k)
    if all(len(s) <= 140 for s in answer.split("\n")): score += 1
    return {"score": score, "notes": notes}

ans_eval = chat("You are concise.", "Explain how to emulsify pasta sauce in 3 lines.")
show_card("Eval — Candidate Answer", body_html="<pre style='white-space:pre-wrap'>" + ans_eval + "</pre>")
show_json(score_answer(ans_eval, must_include=["starchy water","emulsify"]), title="Eval — Score")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Eval — Candidate Answer</div><div class="nb-sub"></div><div class="nb-body"><pre style='white-space:pre-wrap'>To emulsify pasta sauce, slowly incorporate a fat (like olive oil) into the sauce while whisking or stirring vigorously. Use a small amount of reserved pasta cooking water to help the mixture bind together. Continuously mix until the sauce reaches a creamy consistency and coats the pasta evenly.</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Eval — Score</div><div class="nb-sub"></div><div class="nb-body"><pre style="white-space:pre-wrap">{
#   &quot;score&quot;: 1,
#   &quot;notes&quot;: [
#     &quot;Missing: starchy water&quot;
#   ]
# }</pre></div></div>

# %% [markdown]
# ## 14) 🔍 Dual-Mode Self-Test

# %%
from time import perf_counter

def _tiny_self_test(mode):
    global MODE, chat_client
    prev = MODE
    MODE = mode.upper()
    try:
        if is_online():
            chat_client = GLChatClient(GL_OpenAI)
        else:
            chat_client = FakeLM()
    except Exception as e:
        return {"mode": MODE, "status": "error", "error": str(e)}

    report = {"mode": MODE, "status": "ok", "steps": []}
    t0 = perf_counter()
    try:
        ans, hits = rag_task("How to emulsify pasta sauce briefly?")
        report["steps"].append({"task_rag_hits": [n for n,_,_ in hits], "ans_len": len(str(ans))})
        a, h, c = rag_cuisine("japanese", "Quick miso soup idea", cuisine_hint="japanese", top_k=2)
        report["steps"].append({"cuisine_hits": [k for k,_,_ in h], "coverage": c})
        _r = rate_candidate({"name":"Pat","bio":"2y line cook; strong sanitation.","task":"Make tomato pasta"})
        report["steps"].append({"bias_eval_len": len(str(_r))})
        _plan = planner("Cook a simple tomato pasta fast")
        report["steps"].append({"plan_len": len(str(_plan))})
    except Exception as e:
        report["status"] = "error"
        report["error"] = str(e)
    report["elapsed_s"] = round(perf_counter()-t0, 2)
    MODE = prev
    try:
        if is_online():
            chat_client = GLChatClient(GL_OpenAI)
        else:
            chat_client = FakeLM()
    except:
        pass
    return report

offline_report = _tiny_self_test("OFFLINE")
online_report = {"mode":"ONLINE","status":"skipped","reason":"No key or network disabled"}
try:
    if is_online():
        online_report = _tiny_self_test("ONLINE")
    else:
        online_report = {"mode":"ONLINE","status":"skipped","reason":"is_online()==False (no GL key set)"}
except Exception as e:
    online_report = {"mode":"ONLINE","status":"error","error":str(e)}

show_json(offline_report, title="Self-Test — OFFLINE")
show_json(online_report, title="Self-Test — ONLINE")
summary_ok = {"offline_ok": offline_report.get("status")=="ok",
              "online_ok": online_report.get("status")=="ok"}
show_badge("Self-Test Summary", summary_ok["offline_ok"] and summary_ok["online_ok"],
           note="offline_ok=" + str(summary_ok["offline_ok"]) + ", online_ok=" + str(summary_ok["online_ok"]))
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Self-Test — OFFLINE</div><div class="nb-sub"></div><div class="nb-body"><pre style="white-space:pre-wrap">{
#   &quot;mode&quot;: &quot;OFFLINE&quot;,
#   &quot;status&quot;: &quot;ok&quot;,
#   &quot;steps&quot;: [
#     {
#       &quot;task_rag_hits&quot;: [
#         &quot;tomato_sauce.md&quot;,
#         &quot;pasta_basics.md&quot;,
#         &quot;knife_safety.md&quot;
#       ],
#       &quot;ans_len&quot;: 166
#     },
#     {
#       &quot;cuisine_hits&quot;: [
#         &quot;miso_soup&quot;,
#         &quot;tamago_yaki&quot;
#       ],
#       &quot;coverage&quot;: {
#         &quot;coverage&quot;: 0.0,
#         &quot;found&quot;: [],
#         &quot;missing&quot;: [
#           &quot;dashi&quot;,
#           &quot;katsuobushi&quot;,
#           &quot;miso&quot;,
#           &quot;nori&quot;,
#           &quot;scallions&quot;,
#           &quot;tamago&quot;,
#           &quot;tofu&quot;,
#           &quot;umeboshi&quot;,
#           &quot;wakame&quot;
#         ]
#       }
#     },
#     {
#       &quot;bias_eval_len&quot;: 59
#     },
#     {
#       &quot;plan_len&quot;: 59
#     }
#   ],
#   &quot;elapsed_s&quot;: 0.0
# }</pre></div></div>
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Self-Test — ONLINE</div><div class="nb-sub"></div><div class="nb-body"><pre style="white-space:pre-wrap">{
#   &quot;mode&quot;: &quot;ONLINE&quot;,
#   &quot;status&quot;: &quot;ok&quot;,
#   &quot;steps&quot;: [
#     {
#       &quot;task_rag_hits&quot;: [
#         &quot;tomato_sauce.md&quot;,
#         &quot;pasta_basics.md&quot;,
#         &quot;knife_safety.md&quot;
#       ],
#       &quot;ans_len&quot;: 60
#     },
#     {
#       &quot;cuisine_hits&quot;: [
#         &quot;miso_soup&quot;,
#         &quot;tamago_yaki&quot;
#       ],
#       &quot;coverage&quot;: {
#         &quot;coverage&quot;: 0.5555555555555556,
#         &quot;found&quot;: [
#           &quot;dashi&quot;,
#           &quot;miso&quot;,
#           &quot;scallions&quot;,
#           &quot;tofu&quot;,
#           &quot;wakame&quot;
#         ],
#         &quot;missing&quot;: [
#           &quot;katsuobushi&quot;,
#           &quot;nori&quot;,
#           &quot;tamago&quot;,
#           &quot;umeboshi&quot;
#         ]
#       }
#     },
#     {
#       &quot;bias_eval_len&quot;: 421
#     },
#     {
#       &quot;plan_len&quot;: 1318
#     }
#   ],
#   &quot;elapsed_s&quot;: 15.76
# }</pre></div></div>
# <div class="nb-card"><div class="nb-title">Self-Test Summary<span class="nb-badge" style="border-color:#10b981;color:#10b981;">PASS</span></div><div class="nb-body">offline_ok=True, online_ok=True</div></div>

# %% [markdown]
# ## 15) 🧩 Smolagents Framing

# %%
from typing import Callable, Dict, List

Tool = Callable[[dict], dict]
TOOLS: Dict[str, Tool] = {}

def register_tool(name):
    def deco(fn):
        TOOLS[name] = fn
        return fn
    return deco

@register_tool("retrieve_task_tool")
def retrieve_task_tool(inp):
    q = inp.get("query","")
    k = int(inp.get("k", 3))
    hits = retrieve_task(q, k=k)
    return {"tool":"retrieve_task_tool", "query": q, "hits": [{"name": n, "score": s} for n,_,s in hits]}

@register_tool("cuisine_search_tool")
def cuisine_search_tool(inp):
    corpus = inp.get("corpus","global")
    q = inp.get("query","")
    top_k = int(inp.get("top_k", 3))
    docs = cuisine_corpora.get(corpus, [])
    idx = build_cuisine_index(docs)
    hits = search_cuisine(idx, q, top_k=top_k)
    return {"tool":"cuisine_search_tool", "corpus": corpus, "query": q, "hits": [{"key":k, "score":float(s)} for k,_,s in hits]}

class Agent:
    def __init__(self, name, allowed_tools):
        self.name = name; self.allowed_tools = allowed_tools
    def act(self, observation):
        tool_list = ", ".join(self.allowed_tools)
        system = "You are " + self.name + ". You may call one tool: " + tool_list + ". Return JSON {'tool':<name>,'args':{...}}."
        user = "Observation: " + str(observation)
        resp = chat(system, user)
        chosen = None; args = {}
        if isinstance(resp, str) and "tool" in resp:
            try:
                s = resp.replace("'", '"')
                import json as _json
                parsed = _json.loads(s)
                chosen = parsed.get("tool")
                args = parsed.get("args", {})
            except Exception:
                chosen = self.allowed_tools[0]; args = observation
        else:
            chosen = self.allowed_tools[0]; args = observation
        if chosen not in TOOLS: return {"error":"unknown tool", "raw":resp}
        out = TOOLS[chosen](args)
        return {"agent": self.name, "tool_result": out}

class RetrieverAgent(Agent):
    def __init__(self): super().__init__("RetrieverAgent", ["retrieve_task_tool","cuisine_search_tool"])

# %% [markdown]
# ## 16) Orchestrations & Pretty Displays

# %%
class ConversationalDuo:
    def __init__(self, turns=5, corpus="global", stop_on_hits=False, min_turns=2):
        self.a = RetrieverAgent()
        self.turns = turns
        self.corpus = corpus
        self.stop_on_hits = stop_on_hits
        self.min_turns = min_turns

    def run(self, query):
        transcript = []
        obs = {"query": query, "k": 2, "corpus": self.corpus, "top_k": 3}
        for t in range(self.turns):
            out_a = self.a.act(obs)
            transcript.append({"turn": t, "agent":"Retriever", "out": out_a})
            obs = {**obs, "last_tool_result": out_a.get("tool_result", {})}

            hits = out_a.get("tool_result", {}).get("hits", [])
            if self.stop_on_hits and t+1 >= self.min_turns and hits:
                break
        return {"query": query, "transcript": transcript}

duo = ConversationalDuo(turns=5, corpus="japanese")
duo_art = duo.run("Quick miso soup idea")

rows = []
for item in duo_art.get("transcript", [])[:6]:
    tr = item.get("out",{}).get("tool_result",{})
    tool = tr.get("tool") if isinstance(tr, dict) else None
    rows.append({"turn": item.get("turn"), "agent": item.get("agent"), "tool": tool})
show_table(rows, title="Conversational Duo — Transcript (first turns)")
# Out:
# <style>.nb-card{border:1px solid #e5e7eb;border-radius:14px;padding:16px;margin:10px 0;background:#fff;box-shadow:0 1px 2px rgba(0,0,0,0.04);}.nb-title{font-weight:700;font-size:18px;margin-bottom:6px;}.nb-sub{color:#6b7280;font-size:13px;margin-bottom:10px;}.nb-body{font-size:14px;line-height:1.45}.nb-badge{display:inline-block;padding:2px 8px;border-radius:9999px;border:1px solid #e5e7eb;font-size:12px;margin-left:6px;}</style><div class="nb-card"><div class="nb-title">Conversational Duo — Transcript (first turns)</div><div class="nb-sub"></div><div class="nb-body"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>turn</th>
#       <th>agent</th>
#       <th>tool</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>Retriever</td>
#       <td>retrieve_task_tool</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>Retriever</td>
#       <td>cuisine_search_tool</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Retriever</td>
#       <td>retrieve_task_tool</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Retriever</td>
#       <td>cuisine_search_tool</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Retriever</td>
#       <td>retrieve_task_tool</td>
#     </tr>
#   </tbody>
# </table></div></div>
